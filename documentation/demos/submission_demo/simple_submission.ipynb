# %% [markdown]
# # CRDS For Developers
#
#
# Overview
# ========
# This notebook demos a basic command line submission.

# %% [markdown]
# Setup CRDS Server and Cache
# =========================
# >> Setup for a particular server, JWST DEV and /grp/crds/cache for CRDS Content.
#
# >> Another common configuration would be: CRDS_PATH=$HOME/crds_cache_dev.

# %%
import os
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds-bit.stsci.edu"
os.environ["CRDS_PATH"] = os.path.join(os.environ["HOME"], "crds_cache_notebook")

# %% [markdown]
# Setup auth.mast token
# ==================
#
# Probably the best way to set your auth.mast token is to mimic Astroquery and define MAST_API_TOKEN.   If you've already defined MAST_API_TOKEN you can stop.
#
# Otherwise visit https://auth.mast.stsci.edu/token, fill in an identifying name for this token like "CRDS submit"and click the Create Token button. (If you already have a token you can skip this and use it.)
#
# Copy the resulting token string here:

# %%
os.environ["MAST_API_TOKEN"] = "57013171003440ca99eaf50df67747e2"

# %% [markdown]
# **NOTE:**  you must change the hex string below to the one generated by visiting auth.mast above.
#
# CRDS has two other mechanisms for conveying the auth.mast token.   You can set it in the .crds.ini file in your $HOME.   Or you can enter it in response to a prompt for a "password".  auth.mast tokens currently remain valid for 2 weeks.

# %% [markdown]
# Checking Configuration Status
# ------------------------------------
#
# CRDS configuration status can be dumped out using:

# %%
! crds list --status
# Out:
# CRDS Version = '7.3.1, 7.3.1, 55463344'
# CRDS_MODE = 'auto'
# CRDS_PATH = '/Users/jmiller/crds_cache_notebook'
# CRDS_SERVER_URL = 'https://jwst-crds-bit.stsci.edu'
# Cache Locking = 'enabled, multiprocessing'
# Effective Context = 'jwst_0500.pmap'
# Last Synced = '2019-04-09 16:07:10.304086'
# Python Executable = '/Users/jmiller/anaconda3/envs/crds-env/bin/python'
# Python Version = '3.6.6.final.0'
# Readonly Cache = False

# %% [markdown]
# Obtaining test data
# -----------------------
# For the sake of this demo,  you can download a demo reference from the CRDS server like this:

# %%
old_path = os.environ["CRDS_PATH"]
os.environ["CRDS_PATH"] = "/tmp/crds_cache_demo"
# !crds sync --output-dir=. --files jwst_miri_dark_0057.fits --organize=flat
os.environ["CRDS_PATH"] = old_path
! crds_unique CRDSUNIQ *.fits
! crds sync --contexts jwst-edit
# Out:
# CRDS - INFO -  Symbolic context 'jwst-operational' resolves to 'jwst_0500.pmap'
# CRDS - INFO -  Reorganizing 5 references from 'flat' to 'flat'
# CRDS - INFO -  Syncing explicitly listed files.
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  3 infos
# ('jwst_miri_dark_0057.fits', 'CRDSUNIQ', '=', '2019-04-09T16:07:17')
# CRDS - INFO -  Symbolic context 'jwst-edit' resolves to 'jwst_0504.pmap'
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_system_datalvl_0002.rmap      694 bytes  (1 / 124 files) (0 / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_system_calver_0018.rmap    1.8 K bytes  (2 / 124 files) (694 / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_system_0017.imap      385 bytes  (3 / 124 files) (2.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_wavelengthrange_0016.rmap    1.1 K bytes  (4 / 124 files) (2.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_wavecorr_0003.rmap      833 bytes  (5 / 124 files) (4.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_superbias_0029.rmap   11.6 K bytes  (6 / 124 files) (4.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_sflat_0008.rmap    8.5 K bytes  (7 / 124 files) (16.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_saturation_0016.rmap    1.7 K bytes  (8 / 124 files) (24.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_refpix_0012.rmap    1.4 K bytes  (9 / 124 files) (26.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_readnoise_0012.rmap    1.7 K bytes  (10 / 124 files) (28.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_photom_0009.rmap      907 bytes  (11 / 124 files) (29.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_pathloss_0003.rmap      932 bytes  (12 / 124 files) (30.7 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_ote_0019.rmap    1.0 K bytes  (13 / 124 files) (31.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_msaoper_0003.rmap      783 bytes  (14 / 124 files) (32.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_msa_0017.rmap    1.0 K bytes  (15 / 124 files) (33.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_mask_0021.rmap    1.5 K bytes  (16 / 124 files) (34.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_linearity_0016.rmap    1.3 K bytes  (17 / 124 files) (35.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_ipc_0006.rmap      876 bytes  (18 / 124 files) (37.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_ifuslicer_0007.rmap      733 bytes  (19 / 124 files) (38.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_ifupost_0009.rmap      719 bytes  (20 / 124 files) (38.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_ifufore_0007.rmap      719 bytes  (21 / 124 files) (39.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_gain_0018.rmap    1.5 K bytes  (22 / 124 files) (40.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_fpa_0017.rmap    1.0 K bytes  (23 / 124 files) (41.7 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_fore_0016.rmap    3.4 K bytes  (24 / 124 files) (42.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_flat_0012.rmap    3.6 K bytes  (25 / 124 files) (46.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_fflat_0007.rmap    3.3 K bytes  (26 / 124 files) (49.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_extract1d_0010.rmap    1.2 K bytes  (27 / 124 files) (53.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_disperser_0018.rmap    3.9 K bytes  (28 / 124 files) (54.3 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_dflat_0004.rmap    1.0 K bytes  (29 / 124 files) (58.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_dark_0025.rmap   10.6 K bytes  (30 / 124 files) (59.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_cubepar_0005.rmap      740 bytes  (31 / 124 files) (69.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_collimator_0016.rmap    1.1 K bytes  (32 / 124 files) (70.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_camera_0016.rmap    1.0 K bytes  (33 / 124 files) (71.7 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_barshadow_0003.rmap      877 bytes  (34 / 124 files) (72.7 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_area_0010.rmap    4.4 K bytes  (35 / 124 files) (73.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nirspec_0180.imap    2.3 K bytes  (36 / 124 files) (78.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_wfssbkg_0002.rmap    2.3 K bytes  (37 / 124 files) (80.3 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_wavelengthrange_0005.rmap      811 bytes  (38 / 124 files) (82.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_trappars_0004.rmap      753 bytes  (39 / 124 files) (83.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_trapdensity_0004.rmap      774 bytes  (40 / 124 files) (84.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_throughput_0004.rmap      979 bytes  (41 / 124 files) (84.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_superbias_0022.rmap    4.6 K bytes  (42 / 124 files) (85.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_specwcs_0005.rmap    2.3 K bytes  (43 / 124 files) (90.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_saturation_0010.rmap      625 bytes  (44 / 124 files) (92.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_readnoise_0008.rmap      969 bytes  (45 / 124 files) (93.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_photom_0018.rmap      765 bytes  (46 / 124 files) (94.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_persat_0005.rmap      738 bytes  (47 / 124 files) (95.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_pathloss_0002.rmap      707 bytes  (48 / 124 files) (95.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_mask_0013.rmap      735 bytes  (49 / 124 files) (96.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_linearity_0015.rmap      760 bytes  (50 / 124 files) (97.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_ipc_0006.rmap      590 bytes  (51 / 124 files) (98.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_gain_0009.rmap      838 bytes  (52 / 124 files) (98.7 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_flat_0016.rmap    4.1 K bytes  (53 / 124 files) (99.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_extract1d_0006.rmap      854 bytes  (54 / 124 files) (103.7 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_drizpars_0004.rmap      519 bytes  (55 / 124 files) (104.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_distortion_0017.rmap      899 bytes  (56 / 124 files) (105.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_dark_0027.rmap    4.0 K bytes  (57 / 124 files) (105.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_area_0012.rmap    1.1 K bytes  (58 / 124 files) (109.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_niriss_0117.imap    2.0 K bytes  (59 / 124 files) (111.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_wfssbkg_0003.rmap    7.2 K bytes  (60 / 124 files) (113.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_wavelengthrange_0009.rmap      945 bytes  (61 / 124 files) (120.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_tsophot_0002.rmap      794 bytes  (62 / 124 files) (121.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_trappars_0003.rmap    1.6 K bytes  (63 / 124 files) (122.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_trapdensity_0003.rmap    1.6 K bytes  (64 / 124 files) (123.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_superbias_0006.rmap    2.6 K bytes  (65 / 124 files) (125.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_specwcs_0008.rmap    1.7 K bytes  (66 / 124 files) (127.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_saturation_0006.rmap    2.2 K bytes  (67 / 124 files) (129.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_readnoise_0005.rmap    3.0 K bytes  (68 / 124 files) (131.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_psfmask_0002.rmap    9.8 K bytes  (69 / 124 files) (134.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_photom_0006.rmap    2.2 K bytes  (70 / 124 files) (144.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_persat_0004.rmap    1.6 K bytes  (71 / 124 files) (146.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_mask_0007.rmap    2.3 K bytes  (72 / 124 files) (148.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_linearity_0011.rmap    2.4 K bytes  (73 / 124 files) (150.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_ipc_0003.rmap    2.0 K bytes  (74 / 124 files) (152.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_gain_0009.rmap    2.9 K bytes  (75 / 124 files) (154.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_flat_0008.rmap   15.9 K bytes  (76 / 124 files) (157.7 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_drizpars_0001.rmap      519 bytes  (77 / 124 files) (173.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_distortion_0018.rmap    8.0 K bytes  (78 / 124 files) (174.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_dark_0014.rmap    4.9 K bytes  (79 / 124 files) (182.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_area_0006.rmap    4.6 K bytes  (80 / 124 files) (187.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_nircam_0112.imap    2.0 K bytes  (81 / 124 files) (191.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_wcsregions_0009.rmap    1.1 K bytes  (82 / 124 files) (193.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_wavelengthrange_0014.rmap    1.1 K bytes  (83 / 124 files) (194.7 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_tsophot_0002.rmap      780 bytes  (84 / 124 files) (195.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_straymask_0007.rmap      885 bytes  (85 / 124 files) (196.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_specwcs_0021.rmap    2.7 K bytes  (86 / 124 files) (197.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_saturation_0009.rmap      961 bytes  (87 / 124 files) (200.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_rscd_0005.rmap      860 bytes  (88 / 124 files) (201.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_resol_0004.rmap      739 bytes  (89 / 124 files) (202.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_regions_0019.rmap    2.4 K bytes  (90 / 124 files) (202.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_readnoise_0009.rmap    5.3 K bytes  (91 / 124 files) (205.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_psfmask_0002.rmap    1.2 K bytes  (92 / 124 files) (210.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_photom_0015.rmap    1.3 K bytes  (93 / 124 files) (211.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_mask_0012.rmap    1.1 K bytes  (94 / 124 files) (212.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_linearity_0011.rmap    1.9 K bytes  (95 / 124 files) (214.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_ipc_0005.rmap      721 bytes  (96 / 124 files) (215.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_gain_0007.rmap      893 bytes  (97 / 124 files) (216.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_fringe_0010.rmap    1.5 K bytes  (98 / 124 files) (217.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_flat_0032.rmap   20.2 K bytes  (99 / 124 files) (219.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_filteroffset_0018.rmap    1.1 K bytes  (100 / 124 files) (239.3 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_extract1d_0010.rmap    1.0 K bytes  (101 / 124 files) (240.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_drizpars_0002.rmap      511 bytes  (102 / 124 files) (241.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_distortion_0026.rmap    2.3 K bytes  (103 / 124 files) (241.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_dark_0038.rmap    3.4 K bytes  (104 / 124 files) (244.2 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_cubepar_0005.rmap      686 bytes  (105 / 124 files) (247.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_area_0008.rmap      755 bytes  (106 / 124 files) (248.3 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_miri_0162.imap    2.1 K bytes  (107 / 124 files) (249.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_trappars_0004.rmap      903 bytes  (108 / 124 files) (251.1 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_trapdensity_0004.rmap      930 bytes  (109 / 124 files) (252.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_superbias_0013.rmap    3.8 K bytes  (110 / 124 files) (253.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_saturation_0009.rmap      779 bytes  (111 / 124 files) (256.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_readnoise_0011.rmap    1.3 K bytes  (112 / 124 files) (257.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_photom_0008.rmap    1.1 K bytes  (113 / 124 files) (258.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_persat_0004.rmap      884 bytes  (114 / 124 files) (259.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_mask_0018.rmap    1.2 K bytes  (115 / 124 files) (260.8 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_linearity_0013.rmap      925 bytes  (116 / 124 files) (262.0 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_ipc_0003.rmap      614 bytes  (117 / 124 files) (262.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_gain_0010.rmap      890 bytes  (118 / 124 files) (263.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_flat_0009.rmap    1.1 K bytes  (119 / 124 files) (264.4 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_distortion_0007.rmap    1.1 K bytes  (120 / 124 files) (265.5 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_dark_0009.rmap    3.3 K bytes  (121 / 124 files) (266.6 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_area_0009.rmap    1.0 K bytes  (122 / 124 files) (269.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_fgs_0073.imap    1.8 K bytes  (123 / 124 files) (270.9 K / 273.3 K bytes)
# CRDS - INFO -  Fetching  /Users/jmiller/crds_cache_notebook/mappings/jwst/jwst_0504.pmap      573 bytes  (124 / 124 files) (272.7 K / 273.3 K bytes)
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  125 infos

# %% [markdown]
# CRDS Submit Command Line Tool
# ===========================
#
# The crds submit command line tool is a CRDS client utility which interacts with the server and is embedded in the ReDCaT tools.
#
# **IMPORTANT:**   Additional setup is required to run command line file submissions.   Briefly,  you need ssh access to pldmsins1,  membership in group crdsoper, a CRDS server file,  and setup for a .crds.ini files.
#
# See:   https://innerspace.stsci.edu/display/CRDS/Command+Line+File+Submissions

# %% [markdown]
# In the log output, >> indicates progress messages being emitted from the server in real time.
#
# The same >> messages show up on a web page for through-the-web submissions.
#
# Adding --verbose shows DEBUG log messages which show more detail, particularly web operations.  --verbosity=80 shows even more detail which can be helpful for debugging failed web interactions.
#
# The command line interface does a hand over to the web server for review and confirmation,  server actions result in STARTED, READY / BAD FILES / FAIL, and CONFIRMED / FORCED e-mails sent to the crds-servers@stsci.edu mailing list (devs) and redcat@stsci.edu.

# %%
! crds submit --logout
! crds rc_submit --redcat-parameters rc_submit.yaml --files jwst_miri_dark_0057.fits --keep-existing-files --monitor --wait --log-time --stats --creator "Todd Miller" --description "Small scale command line submission test."

# %%
from crds.submit import rc_submit
script = rc_submit.Submission("jwst", "bit")
script["deliverer"] = "Todd Miller"
script["other_email"] = ""
script["file_type"] = "DARK"
script["history_updated"] = True
script["descrip_updated"] = True
script["useafter_updated"] = True
script["useafter_matches"] = True
script["pedigree_updated"] = True
script["keywords_checked"] = True
script["compliance_verified"] = "Yes"
script["ingest_files"] = True
script["etc_delivery"] = False
script["jwst_etc"] = "No"
script["calpipe_version"] = "xxx, 1.0"
script["replacement_files"] = "Yes"
script["old_reference_files"] = "xxx"
script["replacing_badfiles"] = "No"
script["jira_issue"] = "xxx"
script["table_rows_changed"] = "xxx"
script["modes_affected"] = "xxxx"
script["correctness_testing"] = "lots"
script["additional_considerations"] = "a few"
script["change_level"] = "SEVERE"
script["description"] = "something very wordy"
script["instrument"] = "MIRI"
script.add_file("jwst_miri_dark_0057.fits")

# %%
script.validate()

# %%
script.submit()
# Out:
# 2019-04-09 16:07:54,247 - CRDS - INFO -  =============================== setting up ===============================
# INFO:CRDS: =============================== setting up ===============================
# YAML FILE:   /var/folders/s1/wccm27493mb1mlx5cy0rmn780003j5/T/tmp4tnp5hcz.yml
# ['crds.submit', '--files', 'jwst_miri_dark_0057.fits', '--monitor-processing', '--wait-for-completion', '--wipe-existing-files', '--certify-files', '--log-time', '--stats', '--creator', 'someone', '--change-level', 'SEVERE', '--description', 'something very wordy']
# 2019-04-09 16:07:54,487 - CRDS - INFO -  Symbolic context 'jwst-edit' resolves to 'jwst_0504.pmap'
# INFO:CRDS: Symbolic context 'jwst-edit' resolves to 'jwst_0504.pmap'
# 2019-04-09 16:07:54,489 - CRDS - INFO -  ########################################
# INFO:CRDS: ########################################
# 2019-04-09 16:07:54,491 - CRDS - INFO -  Certifying './jwst_miri_dark_0057.fits' (1/1) as 'FITS' relative to context 'jwst_0504.pmap'
# INFO:CRDS: Certifying './jwst_miri_dark_0057.fits' (1/1) as 'FITS' relative to context 'jwst_0504.pmap'
# 2019-04-09 16:07:54,661 - CRDS - INFO -  FITS file 'jwst_miri_dark_0057.fits' conforms to FITS standards.
# INFO:CRDS: FITS file 'jwst_miri_dark_0057.fits' conforms to FITS standards.
# 2019-04-09 16:07:56,398 - CRDS - WARNING -  Missing suggested keyword 'META.MODEL_TYPE [DATAMODL]'
# WARNING:CRDS: Missing suggested keyword 'META.MODEL_TYPE [DATAMODL]'
# 2019-04-09 16:07:56,509 - CRDS - INFO -  [0] DETECTOR MIRIFULONG
# INFO:CRDS: [0] DETECTOR MIRIFULONG
# 2019-04-09 16:07:56,512 - CRDS - INFO -  [0] EXP_TYPE MIR_MRS
# INFO:CRDS: [0] EXP_TYPE MIR_MRS
# 2019-04-09 16:07:56,525 - CRDS - INFO -  META.AUTHOR [AUTHOR] = 'JANE MORRISON'
# INFO:CRDS: META.AUTHOR [AUTHOR] = 'JANE MORRISON'
# 2019-04-09 16:07:56,527 - CRDS - INFO -  META.DESCRIPTION [DESCRIP] = 'MIRI Dark Correction for MIRI'
# INFO:CRDS: META.DESCRIPTION [DESCRIP] = 'MIRI Dark Correction for MIRI'
# 2019-04-09 16:07:56,529 - CRDS - INFO -  META.EXPOSURE.GROUPGAP [GROUPGAP] = 0
# INFO:CRDS: META.EXPOSURE.GROUPGAP [GROUPGAP] = 0
# 2019-04-09 16:07:56,532 - CRDS - INFO -  META.EXPOSURE.NFRAMES [NFRAMES] = 1
# INFO:CRDS: META.EXPOSURE.NFRAMES [NFRAMES] = 1
# 2019-04-09 16:07:56,535 - CRDS - INFO -  META.EXPOSURE.NGROUPS [NGROUPS] = 45
# INFO:CRDS: META.EXPOSURE.NGROUPS [NGROUPS] = 45
# 2019-04-09 16:07:56,537 - CRDS - INFO -  META.EXPOSURE.READPATT [READPATT] = 'SLOW'
# INFO:CRDS: META.EXPOSURE.READPATT [READPATT] = 'SLOW'
# 2019-04-09 16:07:56,539 - CRDS - INFO -  META.EXPOSURE.TYPE [EXP_TYPE] = 'MIR_MRS'
# INFO:CRDS: META.EXPOSURE.TYPE [EXP_TYPE] = 'MIR_MRS'
# 2019-04-09 16:07:56,540 - CRDS - INFO -  META.HISTORY [HISTORY] = 'SEE MIRI-TN-00007-UA-Mean-Dark.PDF for details\nFit was done correcting for nonlinearity and RSCD Correction\nOne solution rejected first 10 frames and last frame\nSecond solution corrected all the frames for nonlinearity and RSCD\nBecause of drifting zero points, first solution was used to find frame v\nframe value at time = 0 was subtracted off all the data\nresulting residuals were binned and average\n a linear fits was performed on the residuals to extrapolate the dark re\n the number of frames used in the fit is defined by NGVALID\n The mean dark residuals were used for frames with valid data, out side\nDATA USED: to create dark CV3  IMG_RAD_01, IMG_RAD_13\nDOCUMENT: MIRI-TR-00007-UA-Dark_06.00.pdf\nSOFTWARE: idl code create_dark_CDP6.pro merge_int_CDP6\nDIFFERENCES: darks now have two integrations\nCreated from: MiriDarkReferenceModel'
# INFO:CRDS: META.HISTORY [HISTORY] = 'SEE MIRI-TN-00007-UA-Mean-Dark.PDF for details\nFit was done correcting for nonlinearity and RSCD Correction\nOne solution rejected first 10 frames and last frame\nSecond solution corrected all the frames for nonlinearity and RSCD\nBecause of drifting zero points, first solution was used to find frame v\nframe value at time = 0 was subtracted off all the data\nresulting residuals were binned and average\n a linear fits was performed on the residuals to extrapolate the dark re\n the number of frames used in the fit is defined by NGVALID\n The mean dark residuals were used for frames with valid data, out side\nDATA USED: to create dark CV3  IMG_RAD_01, IMG_RAD_13\nDOCUMENT: MIRI-TR-00007-UA-Dark_06.00.pdf\nSOFTWARE: idl code create_dark_CDP6.pro merge_int_CDP6\nDIFFERENCES: darks now have two integrations\nCreated from: MiriDarkReferenceModel'
# 2019-04-09 16:07:56,544 - CRDS - INFO -  META.INSTRUMENT.BAND [BAND] = 'ANY'
# INFO:CRDS: META.INSTRUMENT.BAND [BAND] = 'ANY'
# 2019-04-09 16:07:56,546 - CRDS - INFO -  META.INSTRUMENT.CHANNEL [CHANNEL] = 34
# INFO:CRDS: META.INSTRUMENT.CHANNEL [CHANNEL] = 34
# 2019-04-09 16:07:56,548 - CRDS - INFO -  META.INSTRUMENT.CORONAGRAPH [CORONMSK] = 'UNDEFINED'
# INFO:CRDS: META.INSTRUMENT.CORONAGRAPH [CORONMSK] = 'UNDEFINED'
# 2019-04-09 16:07:56,550 - CRDS - INFO -  META.INSTRUMENT.DETECTOR [DETECTOR] = 'MIRIFULONG'
# INFO:CRDS: META.INSTRUMENT.DETECTOR [DETECTOR] = 'MIRIFULONG'
# 2019-04-09 16:07:56,553 - CRDS - INFO -  META.INSTRUMENT.FILTER [FILTER] = 'UNDEFINED'
# INFO:CRDS: META.INSTRUMENT.FILTER [FILTER] = 'UNDEFINED'
# 2019-04-09 16:07:56,555 - CRDS - INFO -  META.INSTRUMENT.GRATING [GRATING] = 'UNDEFINED'
# INFO:CRDS: META.INSTRUMENT.GRATING [GRATING] = 'UNDEFINED'
# 2019-04-09 16:07:56,557 - CRDS - INFO -  META.INSTRUMENT.NAME [INSTRUME] = 'MIRI'
# INFO:CRDS: META.INSTRUMENT.NAME [INSTRUME] = 'MIRI'
# 2019-04-09 16:07:56,559 - CRDS - INFO -  META.INSTRUMENT.PUPIL [PUPIL] = 'UNDEFINED'
# INFO:CRDS: META.INSTRUMENT.PUPIL [PUPIL] = 'UNDEFINED'
# 2019-04-09 16:07:56,561 - CRDS - INFO -  META.MODEL_TYPE [DATAMODL] = 'UNDEFINED'
# INFO:CRDS: META.MODEL_TYPE [DATAMODL] = 'UNDEFINED'
# 2019-04-09 16:07:56,562 - CRDS - INFO -  META.OBSERVATION.DATE [DATE-OBS] = '2015-08-01'
# INFO:CRDS: META.OBSERVATION.DATE [DATE-OBS] = '2015-08-01'
# 2019-04-09 16:07:56,564 - CRDS - INFO -  META.OBSERVATION.TIME [TIME-OBS] = '00:00:00'
# INFO:CRDS: META.OBSERVATION.TIME [TIME-OBS] = '00:00:00'
# 2019-04-09 16:07:56,565 - CRDS - INFO -  META.PEDIGREE [PEDIGREE] = 'GROUND'
# INFO:CRDS: META.PEDIGREE [PEDIGREE] = 'GROUND'
# 2019-04-09 16:07:56,567 - CRDS - INFO -  META.REFTYPE [REFTYPE] = 'DARK'
# INFO:CRDS: META.REFTYPE [REFTYPE] = 'DARK'
# 2019-04-09 16:07:56,569 - CRDS - INFO -  META.SUBARRAY.FASTAXIS [FASTAXIS] = 1
# INFO:CRDS: META.SUBARRAY.FASTAXIS [FASTAXIS] = 1
# 2019-04-09 16:07:56,573 - CRDS - INFO -  META.SUBARRAY.NAME [SUBARRAY] = 'FULL'
# INFO:CRDS: META.SUBARRAY.NAME [SUBARRAY] = 'FULL'
# 2019-04-09 16:07:56,574 - CRDS - INFO -  META.SUBARRAY.SLOWAXIS [SLOWAXIS] = 2
# INFO:CRDS: META.SUBARRAY.SLOWAXIS [SLOWAXIS] = 2
# 2019-04-09 16:07:56,576 - CRDS - INFO -  META.SUBARRAY.XSIZE [SUBSIZE1] = 1032
# INFO:CRDS: META.SUBARRAY.XSIZE [SUBSIZE1] = 1032
# 2019-04-09 16:07:56,579 - CRDS - INFO -  META.SUBARRAY.XSTART [SUBSTRT1] = 1
# INFO:CRDS: META.SUBARRAY.XSTART [SUBSTRT1] = 1
# 2019-04-09 16:07:56,580 - CRDS - INFO -  META.SUBARRAY.YSIZE [SUBSIZE2] = 1024
# INFO:CRDS: META.SUBARRAY.YSIZE [SUBSIZE2] = 1024
# 2019-04-09 16:07:56,582 - CRDS - INFO -  META.SUBARRAY.YSTART [SUBSTRT2] = 1
# INFO:CRDS: META.SUBARRAY.YSTART [SUBSTRT2] = 1
# 2019-04-09 16:07:56,584 - CRDS - INFO -  META.TELESCOPE [TELESCOP] = 'JWST'
# INFO:CRDS: META.TELESCOPE [TELESCOP] = 'JWST'
# 2019-04-09 16:07:56,586 - CRDS - INFO -  META.USEAFTER [USEAFTER] = '2015-08-01T00:00:00'
# INFO:CRDS: META.USEAFTER [USEAFTER] = '2015-08-01T00:00:00'
# 2019-04-09 16:07:56,588 - CRDS - INFO -  Running fitsverify.
# INFO:CRDS: Running fitsverify.
# 2019-04-09 16:07:56,612 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,615 - CRDS - INFO -  >>               fitsverify 4.18 (CFITSIO V3.440)
# INFO:CRDS: >>               fitsverify 4.18 (CFITSIO V3.440)
# 2019-04-09 16:07:56,617 - CRDS - INFO -  >>               --------------------------------
# INFO:CRDS: >>               --------------------------------
# 2019-04-09 16:07:56,620 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,621 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,623 - CRDS - INFO -  >> File: ./jwst_miri_dark_0057.fits
# INFO:CRDS: >> File: ./jwst_miri_dark_0057.fits
# 2019-04-09 16:07:56,625 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,626 - CRDS - INFO -  >> 7 Header-Data Units in this file.
# INFO:CRDS: >> 7 Header-Data Units in this file.
# 2019-04-09 16:07:56,627 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,630 - CRDS - INFO -  >> =================== HDU 1: Primary Array ===================
# INFO:CRDS: >> =================== HDU 1: Primary Array ===================
# 2019-04-09 16:07:56,631 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,633 - CRDS - INFO -  >>  59 header keywords
# INFO:CRDS: >>  59 header keywords
# 2019-04-09 16:07:56,635 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,637 - CRDS - INFO -  >>  Null data array; NAXIS = 0
# INFO:CRDS: >>  Null data array; NAXIS = 0
# 2019-04-09 16:07:56,638 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,640 - CRDS - INFO -  >> =================== HDU 2: Image Exten. ====================
# INFO:CRDS: >> =================== HDU 2: Image Exten. ====================
# 2019-04-09 16:07:56,642 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,644 - CRDS - INFO -  >>  15 header keywords
# INFO:CRDS: >>  15 header keywords
# 2019-04-09 16:07:56,646 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,648 - CRDS - INFO -  >> SCI 32-bit floating point pixels,  4 axes (1032 x 1024 x 45 x 2),
# INFO:CRDS: >> SCI 32-bit floating point pixels,  4 axes (1032 x 1024 x 45 x 2),
# 2019-04-09 16:07:56,650 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,651 - CRDS - INFO -  >> =================== HDU 3: Image Exten. ====================
# INFO:CRDS: >> =================== HDU 3: Image Exten. ====================
# 2019-04-09 16:07:56,652 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,654 - CRDS - INFO -  >>  15 header keywords
# INFO:CRDS: >>  15 header keywords
# 2019-04-09 16:07:56,656 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,657 - CRDS - INFO -  >> ERR 32-bit floating point pixels,  4 axes (1032 x 1024 x 45 x 2),
# INFO:CRDS: >> ERR 32-bit floating point pixels,  4 axes (1032 x 1024 x 45 x 2),
# 2019-04-09 16:07:56,658 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,660 - CRDS - INFO -  >> =================== HDU 4: Image Exten. ====================
# INFO:CRDS: >> =================== HDU 4: Image Exten. ====================
# 2019-04-09 16:07:56,662 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,663 - CRDS - INFO -  >>  16 header keywords
# INFO:CRDS: >>  16 header keywords
# 2019-04-09 16:07:56,664 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,666 - CRDS - INFO -  >> DQ 32-bit integer pixels,  4 axes (1032 x 1024 x 1 x 2),
# INFO:CRDS: >> DQ 32-bit integer pixels,  4 axes (1032 x 1024 x 1 x 2),
# 2019-04-09 16:07:56,668 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,670 - CRDS - INFO -  >> =================== HDU 5: BINARY Table ====================
# INFO:CRDS: >> =================== HDU 5: BINARY Table ====================
# 2019-04-09 16:07:56,672 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,673 - CRDS - INFO -  >>  21 header keywords
# INFO:CRDS: >>  21 header keywords
# 2019-04-09 16:07:56,675 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,678 - CRDS - INFO -  >>  DQ_DEF  (4 columns x 2 rows)
# INFO:CRDS: >>  DQ_DEF  (4 columns x 2 rows)
# 2019-04-09 16:07:56,679 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,681 - CRDS - INFO -  >>  Col# Name (Units)       Format
# INFO:CRDS: >>  Col# Name (Units)       Format
# 2019-04-09 16:07:56,682 - CRDS - INFO -  >>    1 BIT                  J
# INFO:CRDS: >>    1 BIT                  J
# 2019-04-09 16:07:56,684 - CRDS - INFO -  >>    2 VALUE                J
# INFO:CRDS: >>    2 VALUE                J
# 2019-04-09 16:07:56,685 - CRDS - INFO -  >>    3 NAME                 40A
# INFO:CRDS: >>    3 NAME                 40A
# 2019-04-09 16:07:56,687 - CRDS - INFO -  >>    4 DESCRIPTION          80A
# INFO:CRDS: >>    4 DESCRIPTION          80A
# 2019-04-09 16:07:56,689 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,690 - CRDS - INFO -  >> =================== HDU 6: Image Exten. ====================
# INFO:CRDS: >> =================== HDU 6: Image Exten. ====================
# 2019-04-09 16:07:56,691 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,693 - CRDS - INFO -  >>  8 header keywords
# INFO:CRDS: >>  8 header keywords
# 2019-04-09 16:07:56,695 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,696 - CRDS - INFO -  >> METADATA 8-bit integer pixels,  1 axes (1634),
# INFO:CRDS: >> METADATA 8-bit integer pixels,  1 axes (1634),
# 2019-04-09 16:07:56,697 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,699 - CRDS - INFO -  >> =================== HDU 7: Image Exten. ====================
# INFO:CRDS: >> =================== HDU 7: Image Exten. ====================
# 2019-04-09 16:07:56,700 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,703 - CRDS - INFO -  >>  9 header keywords
# INFO:CRDS: >>  9 header keywords
# 2019-04-09 16:07:56,704 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,706 - CRDS - INFO -  >> FITERR 32-bit floating point pixels,  2 axes (1032 x 1024),
# INFO:CRDS: >> FITERR 32-bit floating point pixels,  2 axes (1032 x 1024),
# 2019-04-09 16:07:56,707 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,709 - CRDS - INFO -  >> ++++++++++++++++++++++ Error Summary  ++++++++++++++++++++++
# INFO:CRDS: >> ++++++++++++++++++++++ Error Summary  ++++++++++++++++++++++
# 2019-04-09 16:07:56,710 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,711 - CRDS - INFO -  >>  HDU#  Name (version)       Type             Warnings  Errors
# INFO:CRDS: >>  HDU#  Name (version)       Type             Warnings  Errors
# 2019-04-09 16:07:56,712 - CRDS - INFO -  >>  1                          Primary Array    0         0
# INFO:CRDS: >>  1                          Primary Array    0         0
# 2019-04-09 16:07:56,715 - CRDS - INFO -  >>  2     SCI                  Image Array      0         0
# INFO:CRDS: >>  2     SCI                  Image Array      0         0
# 2019-04-09 16:07:56,716 - CRDS - INFO -  >>  3     ERR                  Image Array      0         0
# INFO:CRDS: >>  3     ERR                  Image Array      0         0
# 2019-04-09 16:07:56,718 - CRDS - INFO -  >>  4     DQ                   Image Array      0         0
# INFO:CRDS: >>  4     DQ                   Image Array      0         0
# 2019-04-09 16:07:56,719 - CRDS - INFO -  >>  5     DQ_DEF               Binary Table     0         0
# INFO:CRDS: >>  5     DQ_DEF               Binary Table     0         0
# 2019-04-09 16:07:56,720 - CRDS - INFO -  >>  6     METADATA             Image Array      0         0
# INFO:CRDS: >>  6     METADATA             Image Array      0         0
# 2019-04-09 16:07:56,721 - CRDS - INFO -  >>  7     FITERR               Image Array      0         0
# INFO:CRDS: >>  7     FITERR               Image Array      0         0
# 2019-04-09 16:07:56,723 - CRDS - INFO -  >>
# INFO:CRDS: >>
# 2019-04-09 16:07:56,724 - CRDS - INFO -  >> **** Verification found 0 warning(s) and 0 error(s). ****
# INFO:CRDS: >> **** Verification found 0 warning(s) and 0 error(s). ****
# 2019-04-09 16:07:56,727 - CRDS - INFO -  Checking JWST datamodels.
# INFO:CRDS: Checking JWST datamodels.
# DEBUG:jwst.datamodels.util:Opening ./jwst_miri_dark_0057.fits as <class 'jwst.datamodels.reference.ReferenceQuadModel'>
# 2019-04-09 16:07:56,847 - CRDS - WARNING -  NoTypeWarning : jwst.datamodels.util : model_type not found. Opening ./jwst_miri_dark_0057.fits as a ReferenceQuadModel
# WARNING:CRDS: NoTypeWarning : jwst.datamodels.util : model_type not found. Opening ./jwst_miri_dark_0057.fits as a ReferenceQuadModel
# 2019-04-09 16:07:56,907 - CRDS - INFO -  ########################################
# INFO:CRDS: ########################################
# 2019-04-09 16:07:56,910 - CRDS - INFO -  Checking rmap update for ('miri', 'dark') inserting files ['./jwst_miri_dark_0057.fits']
# INFO:CRDS: Checking rmap update for ('miri', 'dark') inserting files ['./jwst_miri_dark_0057.fits']
# 2019-04-09 16:07:56,911 - CRDS - INFO -  Inserting jwst_miri_dark_0057.fits into 'jwst_miri_dark_0038.rmap'
# INFO:CRDS: Inserting jwst_miri_dark_0057.fits into 'jwst_miri_dark_0038.rmap'
# 2019-04-09 16:07:57,053 - CRDS - INFO -  ########################################
# INFO:CRDS: ########################################
# 2019-04-09 16:07:57,055 - CRDS - INFO -  Certifying '/tmp/jwst_miri_dark_0038.rmap' as 'MAPPING' relative to context 'jwst_0504.pmap'
# INFO:CRDS: Certifying '/tmp/jwst_miri_dark_0038.rmap' as 'MAPPING' relative to context 'jwst_0504.pmap'
# 2019-04-09 16:07:58,183 - CRDS - INFO -  ########################################
# INFO:CRDS: ########################################
# 2019-04-09 16:07:58,185 - CRDS - INFO -  Checking local file sha1sums vs. CRDS server to identify files already in CRDS.
# INFO:CRDS: Checking local file sha1sums vs. CRDS server to identify files already in CRDS.
# 2019-04-09 16:07:59,140 - CRDS - INFO -  ########################################
# INFO:CRDS: ########################################
# 2019-04-09 16:07:59,185 - CRDS - INFO -  Logging in aquiring lock.
# INFO:CRDS: Logging in aquiring lock.
# 2019-04-09 16:08:01,276 - CRDS - INFO -  =============================== wipe files ===============================
# INFO:CRDS: =============================== wipe files ===============================
# 2019-04-09 16:08:01,563 - CRDS - INFO -  Preparing server logging.
# INFO:CRDS: Preparing server logging.
# 2019-04-09 16:08:01,744 - CRDS - INFO -  ============================== ingest files ==============================
# INFO:CRDS: ============================== ingest files ==============================
# 2019-04-09 16:08:01,745 - CRDS - INFO -  Uploading 1 file(s) totalling 773.6 M bytes
# INFO:CRDS: Uploading 1 file(s) totalling 773.6 M bytes
# 2019-04-09 16:08:01,925 - CRDS - INFO -  Upload started './jwst_miri_dark_0057.fits' [ 1 / 1  files ] [ 773.6 M / 773.6 M  bytes ]
# INFO:CRDS: Upload started './jwst_miri_dark_0057.fits' [ 1 / 1  files ] [ 773.6 M / 773.6 M  bytes ]
# 2019-04-09 16:09:56,396 - CRDS - INFO -  ===========================================================================
# INFO:CRDS: ===========================================================================
# 2019-04-09 16:09:56,397 - CRDS - INFO -  Posting web request for '/submission_form/redcat_submit/'
# INFO:CRDS: Posting web request for '/submission_form/redcat_submit/'
# CRDS - INFO -  ======= monitoring server on '271ebf48-8fb2-409d-b463-044102f260fa' =======
# INFO:CRDS: ======= monitoring server on '271ebf48-8fb2-409d-b463-044102f260fa' =======
# CRDS - INFO -  >> Starting submission processing.
# INFO:CRDS: >> Starting submission processing.
# CRDS - INFO -  >> Certifying 'jwst_miri_dark_0057.fits'
# INFO:CRDS: >> Certifying 'jwst_miri_dark_0057.fits'
# CRDS - INFO -  >> Resolved old rmap as 'jwst_miri_dark_0038.rmap' based on context 'jwst_0504.pmap'
# INFO:CRDS: >> Resolved old rmap as 'jwst_miri_dark_0038.rmap' based on context 'jwst_0504.pmap'
# CRDS - INFO -  >> Doing trial insertion of 1 references into 'jwst_miri_dark_0038.rmap'
# INFO:CRDS: >> Doing trial insertion of 1 references into 'jwst_miri_dark_0038.rmap'
# CRDS - INFO -  >> Processing 'jwst_miri_dark_0057.fits' [1 / 1 files] [773.6 M / 773.6 M / 773.6 M bytes]
# INFO:CRDS: >> Processing 'jwst_miri_dark_0057.fits' [1 / 1 files] [773.6 M / 773.6 M / 773.6 M bytes]
# CRDS - INFO -  >> Renaming 'jwst_miri_dark_0057.fits' --> 'jwst_miri_dark_0122.fits'
# INFO:CRDS: >> Renaming 'jwst_miri_dark_0057.fits' --> 'jwst_miri_dark_0122.fits'
# CRDS - INFO -  >> Copying 'jwst_miri_dark_0057.fits'
# INFO:CRDS: >> Copying 'jwst_miri_dark_0057.fits'
# CRDS - INFO -  >> Adding file 'jwst_miri_dark_0057.fits' to database.
# INFO:CRDS: >> Adding file 'jwst_miri_dark_0057.fits' to database.
# CRDS - INFO -  >> Generating new rmap 'jwst_miri_dark_0074.rmap' from 'jwst_miri_dark_0038.rmap'.
# INFO:CRDS: >> Generating new rmap 'jwst_miri_dark_0074.rmap' from 'jwst_miri_dark_0038.rmap'.
# CRDS - INFO -  >> Adding file 'jwst_miri_dark_0074.rmap' to database.
# INFO:CRDS: >> Adding file 'jwst_miri_dark_0074.rmap' to database.
# CRDS - INFO -  >> Certifying 'jwst_miri_dark_0074.rmap'
# INFO:CRDS: >> Certifying 'jwst_miri_dark_0074.rmap'
# CRDS - INFO -  >> Checking for derivation collisions.
# INFO:CRDS: >> Checking for derivation collisions.
# CRDS - INFO -  >> Computing file differences.
# INFO:CRDS: >> Computing file differences.
# CRDS - INFO -  >> Differencing 'jwst_miri_dark_0038.rmap' vs. 'jwst_miri_dark_0074.rmap'
# INFO:CRDS: >> Differencing 'jwst_miri_dark_0038.rmap' vs. 'jwst_miri_dark_0074.rmap'
# CRDS - INFO -  >> COMPLETED: https://jwst-crds-bit.stsci.edu//display_result/2851f84a-72bd-4851-9ecb-2eef41dfd30a
# INFO:CRDS: >> COMPLETED: https://jwst-crds-bit.stsci.edu//display_result/2851f84a-72bd-4851-9ecb-2eef41dfd30a
# CRDS - INFO -  ========================= monitoring server done =========================
# INFO:CRDS: ========================= monitoring server done =========================
# CRDS - INFO -  0 errors
# INFO:CRDS: 0 errors
# CRDS - INFO -  2 warnings
# INFO:CRDS: 2 warnings
# CRDS - INFO -  141 infos
# INFO:CRDS: 141 infos
# CRDS - INFO -  STARTED 2019-04-09 16:07:54.24
# INFO:CRDS: STARTED 2019-04-09 16:07:54.24
# CRDS - INFO -  STOPPED 2019-04-09 16:10:38.80
# INFO:CRDS: STOPPED 2019-04-09 16:10:38.80
# CRDS - INFO -  ELAPSED 0:02:44.56
# INFO:CRDS: ELAPSED 0:02:44.56
