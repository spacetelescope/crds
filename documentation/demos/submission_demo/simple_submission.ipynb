# %% [markdown]
# # CRDS For Developers
#
#
# Overview
# ========
# This notebook demos a basic command line submission.

# %% [markdown]
# Setup
# =====
# >> Setup for a particular server, JWST DEV and /grp/crds/cache for CRDS Content.
#
# >> Another common configuration would be: CRDS_PATH=$HOME/crds_cache_dev.

# %%
import os
os.environ["CRDS_SERVER_URL"] = "https://jwst-crds-bit.stsci.edu"
os.environ["CRDS_PATH"] = "/grp/crds/cache"

# %% [markdown]
# Checking Configuration Status
# ------------------------------------
#
# CRDS configuration status can be dumped out using:

# %%
! crds list --status
# Out:
# CRDS Version = '7.3.1, 7.3.1, 55463344'
# CRDS_MODE = 'auto'
# CRDS_PATH = '/grp/crds/cache'
# CRDS_SERVER_URL = 'https://jwst-crds-bit.stsci.edu'
# Cache Locking = 'enabled, multiprocessing'
# Effective Context = 'jwst_0500.pmap'
# Last Synced = '2019-03-27 10:09:28.714229'
# Python Executable = '/Users/jmiller/anaconda3/envs/crds-env/bin/python'
# Python Version = '3.6.8.final.0'
# Readonly Cache = False

# %% [markdown]
# Obtaining test data
# -----------------------
# For the sake of this demo,  you can download a demo reference from the CRDS server like this:

# %%
os.environ["CRDS_PATH"] = "/tmp/crds_cache_demo"
# !crds sync --output-dir=. --files jwst_miri_dark_0057.fits
os.environ["CRDS_PATH"] = "/grp/crds/cache"
# Out:
# CRDS - INFO -  Symbolic context 'jwst-operational' resolves to 'jwst_0500.pmap'
# CRDS - INFO -  Syncing explicitly listed files.
# CRDS - INFO -  0 errors
# CRDS - INFO -  0 warnings
# CRDS - INFO -  2 infos

# %% [markdown]
# CRDS Submit Command Line Tool
# ===========================
#
# The crds submit command line tool is a CRDS client utility which interacts with the server and is embedded in the ReDCaT tools.
#
# **IMPORTANT:**   Additional setup is required to run command line file submissions.   Briefly,  you need ssh access to pldmsins1,  membership in group crdsoper, a CRDS server file,  and setup for a .crds.ini files.
#
# See:   https://innerspace.stsci.edu/display/CRDS/Command+Line+File+Submissions

# %% [markdown]
# In the log output, >> indicates progress messages being emitted from the server in real time.
#
# The same >> messages show up on a web page for through-the-web submissions.
#
# Adding --verbose shows DEBUG log messages which show more detail, particularly web operations.  --verbosity=80 shows even more detail which can be helpful for debugging failed web interactions.
#
# The command line interface does a hand over to the web server for review and confirmation,  server actions result in STARTED, READY / BAD FILES / FAIL, and CONFIRMED / FORCED e-mails sent to the crds-servers@stsci.edu mailing list (devs) and redcat@stsci.edu.

# %%
! crds_unique CRDSUNIQ *.fits
! crds submit --logout 
! crds rc_submit --redcat-parameters rc_submit.yaml --files jwst_miri_dark_0057.fits --wipe-existing-files --monitor --wait --log-time --stats --creator "Todd Miller" --description "Small scale command line submission test." --verbosity=80
# Out:
# ('jwst_miri_dark_0025_a.fits', 'CRDSUNIQ', '=', '2019-03-27T10:09:29')
# ('jwst_miri_dark_0025_b.fits', 'CRDSUNIQ', '=', '2019-04-06T10:09:29')
# ('jwst_miri_dark_0057.fits', 'CRDSUNIQ', '=', '2019-04-16T10:09:29')
# CRDS - INFO -  =============================== setting up ===============================
# CRDS - INFO -  Symbolic context 'jwst-edit' resolves to 'jwst_0504.pmap'
# CRDS - INFO -  Logging out releasing lock.
# 2019-03-27 10:09:40,811 - CRDS - DEBUG -  Command: ['rc_submit.py', '--redcat-parameters', 'rc_submit.yaml', '--files', 'jwst_miri_dark_0057.fits', '--wipe-existing-files', '--monitor', '--wait', '--log-time', '--stats', '--creator', 'Todd Miller', '--description', 'Small scale command line submission test.', '--verbosity=80']
# 2019-03-27 10:09:40,811 - CRDS - INFO -  =============================== setting up ===============================
# 2019-03-27 10:09:40,811 - CRDS - DEBUG -  Uncached call server_info (<__main__.RedCatSubmissionScript object at 0x11896b550>,)
# 2019-03-27 10:09:40,811 - CRDS - DEBUG -  Uncached call observatory (<__main__.RedCatSubmissionScript object at 0x11896b550>,)
# 2019-03-27 10:09:40,811 - CRDS - DEBUG -  Uncached call get_config_info ('jwst',)
# 2019-03-27 10:09:40,811 - CRDS - DEBUG -  Uncached call get_server_info ()
# 2019-03-27 10:09:40,811 - CRDS - DEBUG -  CRDS JSON RPC to https://jwst-crds-bit.stsci.edu/json/get_server_info/rc_submit-7.3.1-656af7d7-ee2e-41a8-b539-7439adcabd52-00000001/ parameters () -->
# 2019-03-27 10:09:40,876 - CRDS - DEBUG -  RPC OK {'bad_files_list': ['jwst_fgs_distortion_0001.asdf',
#                     'jwst_fgs_distortion_0002.asdf',
#                     'jwst_miri_area_0001.fits',
#                     'jwst_miri_cubepar_0001.fits',
#                     'jwst_miri_dark_0008.rmap',
#                     'jwst_miri_flat_0002.rmap',
#                     'jwst_miri_flat_0003.rmap',
#                     'jwst_nircam_distortion_0033.asdf',
#                     'jwst_nircam_distortion_0034.asdf',
#                     'jwst_nircam_distortion_0035.asdf',
#                     'jwst_nircam_distortion_0036.asdf',
#                     'jwst_nircam_distortion_0040.asdf',
#                     'jwst_nircam_distortion_0041.asdf',
#                     'jwst_nircam_distortion_0042.asdf',
#                     'jwst_nircam_distortion_0044.asdf',
#                     'jwst_nircam_distortion_0045.asdf',
#                     'jwst_nircam_distortion_0046.asdf',
#                     'jwst_nirspec_cubepar_0001.fits'],
#  'context_history': [['2018-12-14 11:13:53',
#                       'jwst_0500.pmap',
#                       'Recently all NIRSPEC rmaps changed exposure type equals '
#                       'NRS BOTA to NRS MSATA and NRS WATA.   By appearances '
#                       'NIRSPEC BARSHADOW was missed and this rmap is the '
#                       'updated version.'],
#                      ['2018-12-03 15:43:39',
#                       'jwst_0499.pmap',
#                       'Updated NIRSpec linearity reference rmap where '
#                       'jwst_nirspec_linearity_0004.fits and '
#                       'jwst_nirspec_linearity_0005.fits were removed due to '
#                       'incorrect orientations.   Initial delivery of NIRSpec '
#                       'bias and dark for the SUB512S subarray.'],
#                      ['2018-11-05 10:09:07',
#                       'jwst_0497.pmap',
#                       'NIRSPEC GAIN and LINEARITY rmap updates for Jira '
#                       'CRDS-240 and CRDS-241.'],
#                      ['2018-10-26 09:50:06',
#                       'jwst_0495.pmap',
#                       'Added support for NRSIRS2 to NIRSPEC READPATT rmap as '
#                       'described in Jira CRDS-237.  New rmaps for the NIRSpec '
#                       'camera, collimator, dflat, disperser, extract1d, fflat, '
#                       'flat, fore, fpa, mas, ote, sflat, and wavelengthrange '
#                       'reference files where the EXP_TYPE NRS_BOTA was '
#                       'replaced with NRS_MSATA orbar NRS_WATA. This is in '
#                       'support of Build 7.2. See JIRA issue CRDS 239 for more '
#                       'details.'],
#                      ['2018-10-08 16:13:55',
#                       'jwst_0493.pmap',
#                       'New SYSTEM CALVER reference file for AUI CAL Step '
#                       'version reporting for 0.12.x.'],
#                      ['2018-10-04 17:02:02',
#                       'jwst_0492.pmap',
#                       'Added NIRCAM DARK for SUB320A335R.   Added first '
#                       'PSFMASK references for MIRI and NIRCAM.'],
#                      ['2018-10-02 12:49:18',
#                       'jwst_0489.pmap',
#                       'Updated FGS dark and superbias with new short subarray '
#                       'names.  CENTER changed to CNTR, DIAGONAL changed to '
#                       'DIAG, and LLCORNER changed to LL.  See JIRA issue CRDS '
#                       '236 for more information.'],
#                      ['2018-09-28 13:54:42',
#                       'jwst_0488.pmap',
#                       'Adds new NIRISS and NIRCAM WAVELENGTHRANGE,  NIRISS '
#                       'PATHLOSS,  empty PSFMASK support.'],
#                      ['2018-09-06 11:35:30',
#                       'jwst_0482.pmap',
#                       'New NIRCam wavelengthrange reference file which '
#                       'supports pipeline update to NRC TSGRISM mode.  Revised '
#                       'rmap.'],
#                      ['2018-08-17 13:07:20',
#                       'jwst_0480.pmap',
#                       'Added new NIRISS  DARK and SUPERBIAS files.'],
#                      ['2018-08-01 12:47:53',
#                       'jwst_0478.pmap',
#                       'SCSB has defined a new DQ flag condition REFERENCE '
#                       'PIXEL, which needs to be added to the reference pixel '
#                       'locations in the MASK reference files for all '
#                       'instruments and detectors. The new files are the same '
#                       'as the old versions except that reference pixels are '
#                       'now flagged with the new REFERENCE PIXEL value and the '
#                       'DQ DEF table includes the new REFERENCE PIXEL flag.   '
#                       'Delivered by Graham Kanarek for NIRSPEC.'],
#                      ['2018-07-23 14:21:22',
#                       'jwst_0477.pmap',
#                       'The current version of NIRISS subarray DARK and '
#                       'SUPERBIAS have the PREADPA NIS NISRAPID Readout pattern '
#                       'header keyword, various symbols are missing from the '
#                       'header keyword, but was added outside of the pipeline '
#                       'that creates the dark and bias reference files '
#                       'originally. These files have been created from the '
#                       'darks and biases pipeline.'],
#                      ['2018-07-18 10:28:52',
#                       'jwst_0476.pmap',
#                       'Corrected DQ array orientation for NIRISS FLAT '
#                       'references.   Added MIRI and NIRCAM TSOPHOT rmaps and '
#                       'references for Jira CCD-119,  all other instruments are '
#                       'N/A.'],
#                      ['2018-07-12 16:46:46',
#                       'jwst_0471.pmap',
#                       'Replaced NIRISS FLATs for new data models and updated '
#                       'DQ handling.   Replaced NIRISS DARK and SUPERBIAS files '
#                       'for revised DQ handling.   Replaced FGS MASK files for '
#                       'revised definitions of bad pixels.'],
#                      ['2018-06-06 12:49:16',
#                       'jwst_0468.pmap',
#                       'B7.1.3 final DMS context. \r\n'
#                       '\r\n'
#                       'Updated NIRSPEC gain rmap to add '
#                       'jwst_nirspec_gain_0019.fits and '
#                       'jwst_nirspec_gain_0018.fits for NETA.SUBARRAY.NAME '
#                       'equal to GENERIC for the NRS1 and NRS2 detectors, '
#                       'respectively, so that they will apply to all subarray '
#                       'data taken before April 1 2017 where the gain was 1. '
#                       'For subarray data taken after April 1 2017 where the '
#                       'gain is set to 2, jwst_nirspec_gain_0017.fits for NRS1 '
#                       'and jwst_nirspec_gain_0016.fits for NRS2 will be used,  '
#                       'as discussed in Jira CRDS-216.   Also dropped obsolete '
#                       '3D MIRI DARK files which no longer run with CAL, as '
#                       'discussed in Jira CRDS-206.'],
#                      ['2018-06-01 10:04:11',
#                       'jwst_0465.pmap',
#                       'New NIRSPEC OTE and IFUPOST rmaps where the USEAFTERs '
#                       'for the newest files, jwst_nirspec_ifupost_0004.asdf '
#                       'and jwst_nirspec_ote_0005.asdf, were changed to 2015 11 '
#                       '01 in order for CV3 data to be fully covered by the new '
#                       'files. See JIRA issue CRDS 218 for more information.  '
#                       'For NIRCAM WFSSBKG changed EXP_TYPE  NRC_GRISM to '
#                       'NRC_WFSS in rmap.'],
#                      ['2018-05-29 10:14:37',
#                       'jwst_0463.pmap',
#                       'New NIRCam subarray dark reference files are being '
#                       'delivered for missing subarray SUB400P for detectors '
#                       'NRCB1, NRCB2 and NRCB4. These new darks were generated '
#                       'using CV3 data and are being delivered for use with the '
#                       'JWST Build 7.1 calibration pipeline. Delivered by Brian '
#                       'Brooks for NIRCAM.   Also add support new NIRISS '
#                       'DISTORTION.'],
#                      ['2018-05-22 14:58:05',
#                       'jwst_0461.pmap',
#                       'Reverted to jwst_0461.pmap since new NIRISS DISTORTION '
#                       'coefficients in jwst_0462.pmap have not run regression '
#                       'tests yet.'],
#                      ['2018-05-22 14:52:52',
#                       'jwst_0462.pmap',
#                       'Replacement NIRISS DISTORTION reference.   Updated '
#                       'NIRSPEC SFLAT rmap for NRS_AUTOWAVE.    Removed '
#                       'jwst_niriss_linearity_0006.fits due to '
#                       'jwst_niriss_linearity_0011.fits having updated '
#                       'coefficients.    Updated MIRI photom reference rmap '
#                       'where the entries for the MIRIFULONG and MIRIFUSHORT '
#                       'detectors with BAND set to NA were removed.   Fixed '
#                       'typo in the bad pixel mask that has been corrected and '
#                       'new NIRISS linearity coefficients were derived.'],
#                      ['2018-05-14 11:26:54',
#                       'jwst_0456.pmap',
#                       'Reverted to jwst_0456.pmap for formal release to DMS '
#                       '7.1.3 testing.   Drops SYSTEM CALVER update not '
#                       'critical to pipeline operation.'],
#                      ['2018-05-11 20:36:04',
#                       'jwst_0457.pmap',
#                       'NIRSPEC SFLAT and FFLAT handling for FILTER=OPAQUE for '
#                       'exposure types NRS_MSASPEC, NRS_FIXEDSLIT, and '
#                       'NRS_IFU.  CAL s/w versions reference for B7.1.3.'],
#                      ['2018-04-28 12:15:03',
#                       'jwst_0454.pmap',
#                       'Updated NIRCAM MASK references,  new DQ flag REFERENCE '
#                       'PIXEL.  Added NIRISS WFSSBKG references.   Updated MIRI '
#                       'MASK +  SATURATION references.   Update for MIRI RSCD '
#                       'table formats, REQUIRES recent JWST CAL code update.  '
#                       'Updated NIRSPEC OTE and IFUPOST references.'],
#                      ['2018-04-10 12:06:13',
#                       'jwst_0445.pmap',
#                       'Added WFSSBKG reference type for all instruments.   '
#                       'Added initial rmap and WFSSBKG reference files for '
#                       'NIRCAM.   All for Jira CRDS-184.'],
#                      ['2018-03-28 08:35:33',
#                       'jwst_0442.pmap',
#                       'The current version of the GUIDER1 and GUIDER2 '
#                       'Distortion reference files in CRDS were not set up in '
#                       'the way the JWST Calibration Pipeline expects and do '
#                       'not work in the pipeline. These 2 new files will be '
#                       'able to be used in the pipeline. The header keywords '
#                       'EXP TYPE and DETECTOR used in the selection criteria '
#                       'for this file will be the same as in the current files. '
#                       'Delivered by Shannon Osborne for FGS.'],
#                      ['2018-03-28 08:34:34',
#                       'jwst_0441.pmap',
#                       'An inconsistency was found in that the IPC inverse '
#                       'kernal was not updated the last time IPC kernal values '
#                       'were derived from CV3 darks. This was found in the '
#                       'current IPC reference file that needed to be corrected. '
#                       'This is now been removed. Delivered by Michael A. Wolfe '
#                       'for NIRISS.'],
#                      ['2018-03-23 15:31:23',
#                       'jwst_0440.pmap',
#                       'Updated NIRCAM GAIN reference files from cv3 data, '
#                       'produced using the new dptc method, and accounting for '
#                       'low epoxy regions on the detectors. these gain maps are '
#                       'more accurate than the previous version.\r\n'
#                       '\r\n'
#                       'New MIRI CUBEPAR references,  requires CAL code '
#                       'update.\r\n'
#                       '\r\n'
#                       'Replacement NIRSPEC DARK and SUPERBIAS references '
#                       'fixing bad SUBSTRT2 keyword values from 2016 and '
#                       '2017.\r\n'
#                       '\r\n'
#                       'Update to NIRSPEC SUPERBIAS rmap adjusting or-patterns '
#                       'for NRS or NRSRAPID and removing one '
#                       'conflicting/redundant reference, 0098 replaced by '
#                       '0148.'],
#                      ['2018-03-05 10:31:18',
#                       'jwst_0435.pmap',
#                       'New FGS mask and flat rmaps where META.EXPOSURE.TYPE '
#                       'has been added as a matching parameter. See JIRA issue '
#                       'CRDS 174 for more information.'],
#                      ['2018-02-22 15:17:57',
#                       'jwst_0434.pmap',
#                       'NIRCAM PHOTOM change the old PUPIL values of GRISMV2 '
#                       'and GRISMV3 to GRISMR and GRISMC, and also added '
#                       'several new rows so that there is coverage for both '
#                       'grisms using all 12 possible FILTER values.  NIRISS '
#                       'MASK DQ value update for current understanding of bad '
#                       'pixels.'],
#                      ['2018-02-16 14:35:44',
#                       'jwst_0432.pmap',
#                       'Manual update of the JWST pmap.  The update included '
#                       'changing the NIRSPEC imap to version 0159, which has '
#                       'the rmap entries for the persat, trapdensity, and '
#                       'trappars references set to NA.'],
#                      ['2018-02-02 15:53:42',
#                       'jwst_0431.pmap',
#                       'The new reference file was delivered because the '
#                       'original had units of electrons instead of ADUs in the '
#                       'science extension. Now the science extension has units '
#                       'of ADUs.    Delivered by  Michael A. Wolfe for NIRISS.'],
#                      ['2018-01-29 15:52:36',
#                       'jwst_0430.pmap',
#                       'Revised NIRSPEC SUBARRAY names e.g. S200A1 renamed as '
#                       'SUBS200A1.'],
#                      ['2018-01-16 15:48:00',
#                       'jwst_0428.pmap',
#                       'New FGS Bad Pixel Mask and Pixel Flat reference files '
#                       'are needed for FGS ID STACKED images, which have a '
#                       'different size than FGS Calibration and FGS ID IMAGE '
#                       'images.  New NIRISS FLAT references.   Obsolete V2V3 '
#                       'references removed for all references per Jira '
#                       'CRDS-160.'],
#                      ['2018-01-02 10:09:07',
#                       'jwst_0425.pmap',
#                       'NIRCam pixel flats were derived from CV3 data taken '
#                       'after October 2015. The files were updated since there '
#                       'were issues with the error extension having values of '
#                       'zeros. Delivered by Brian Brooks for NIRCAM.'],
#                      ['2017-12-18 23:38:25',
#                       'jwst_0424.pmap',
#                       'Real NIRCAM PERSAT references added.   Rmap update for '
#                       'NIRISS EXTRACT1D exposure type NIS_WFSS.'],
#                      ['2017-11-13 12:25:12',
#                       'jwst_0422.pmap',
#                       'B7.1 final context.   Corrections to NIRSPEC SUPERBIAS '
#                       'rmaps related to ALLIRS2 patterns and P_ keywords. '
#                       'Expanded coverage for NIRCAM FLAT rmap.'],
#                      ['2017-11-10 14:34:17',
#                       'jwst_0419.pmap',
#                       'NIRCAM DARK backward compatible SUBARRAY names  '
#                       'MASKA210R, MASKA430R, MASKBSWB, MASKBLWB.\r\n'
#                       'NIRISS new DISTORTION, DRIZPARS, LINEARITY, PHOTOM, '
#                       'SATURATION references.\r\n'
#                       'NIRSPEC DARK SUBSTRT1/XSIZE is 3200 should be 2048 rmap '
#                       'fix,  reference keyword SUBSTRT1 remains 3200.'],
#                      ['2017-11-06 14:48:09',
#                       'jwst_0414.pmap',
#                       'Updated SYSTEM CALVER for 0.7.8rc6 - rc9, FGS '
#                       'READNOISE, NIRCAM DARK.'],
#                      ['2017-10-21 01:35:55',
#                       'jwst_0410.pmap',
#                       'Updated NIRSPEC MASK rmap for Jira REDCAT 37, FGS '
#                       'READNOISE rmap for Jira REDCAT 38, NIRSPEC REFPIX '
#                       'references from Dec 2016 reactivated, NIRSPEC DARK rmap '
#                       'updated for applicable READPATT NRS or NRSRAPID.'],
#                      ['2017-10-12 13:24:58',
#                       'jwst_0406.pmap',
#                       'NIRSPEC DARK, SUPERBIAS, LINERARITY, READNOISE, '
#                       'SATURATION references for new detectors.  FGS bad pixel '
#                       'MASK references with DQ=0.'],
#                      ['2017-10-03 16:57:08',
#                       'jwst_0401.pmap',
#                       'Add NIRSPEC imaging FLATs, BARSHADOW.   Updated NIRSPEC '
#                       'EXTRACT1D and SUPERBIAS rmaps.  New NIRSPEC IPC and '
#                       'MASK references.  Added SYSTEM CALVER reference for '
#                       '0.7.8rc1,2,3,4.    Last regression context prior to CAL '
#                       'code 0.7.8rc3 I-and-T pre-release.'],
#                      ['2017-09-26 13:11:07',
#                       'jwst_0391.pmap',
#                       'FGS persistence references added.\r\n'
#                       '\r\n'
#                       'MIRI set WAVECORR and MSAOPER to N/A.\r\n'
#                       '\r\n'
#                       'NIRCAM AREA references.\r\n'
#                       'NIRCAM DISTORTION references + updates.\r\n'
#                       'NIRCAM GAIN replacement references.\r\n'
#                       '\r\n'
#                       'NIRISS DARK reference replacement.\r\n'
#                       'NIRISS EXTRACT1D support for NIS_SOSS.\r\n'
#                       'NIRISS FLAT replacements.\r\n'
#                       'NIRISS GAIN generic replacement.\r\n'
#                       'NIRISS PERSAT, TRAPPARS, TRAPDENSITY references '
#                       'added.\r\n'
#                       'NIRISS PHOTOM reference replaced.\r\n'
#                       'NIRISS SPECWCS references + rmap update.\r\n'
#                       'NIRISS SUPERBIAS references + updates.\r\n'
#                       '\r\n'
#                       'NIRSPEC CAMERA, COLLIMATOR handle NRS_AUTOWAVE.\r\n'
#                       'NIRSPEC DFLAT, FFLAT, SFLAT handling for AUTOWAVE + '
#                       'imaging modes.\r\n'
#                       'NIRSPEC FLAT added back empty for imaging mode '
#                       'references to come,  handles spec modes as N/A.\r\n'
#                       'NIRSPEC DISPERSER, FORE, FPA, OTE  MSA, WAVELENGTHRANGE '
#                       'handle NRS_AUTOWAVE.\r\n'
#                       'NIRSPEC replaced GAIN, LINEARITY, READNOISE '
#                       'references.\r\n'
#                       'NIRSPEC MSAOPER same reference all cases.\r\n'
#                       'NIRSPEC SATURATION new + replaced references.'],
#                      ['2017-08-18 14:30:57',
#                       'jwst_0361.pmap',
#                       'Temporary rollback until NIRCAM SPECWCS references are '
#                       'delivered.'],
#                      ['2017-08-17 17:53:39',
#                       'jwst_0365.pmap',
#                       'Added empty rmap for NIRSPEC WAVECORR.'],
#                      ['2017-08-17 17:08:06',
#                       'jwst_0364.pmap',
#                       'PERSAT, TRAPPARS, TRAPDENSITY rmaps added USEAFTER '
#                       'support.\r\n'
#                       'NIRSPEC SATURATION added SUBARRAY as matching '
#                       'criteria.\r\n'
#                       'NIRSPEC references for SUBARRAY using GAIN 2.\r\n'
#                       'NIRSPEC AREA is N/A for NRS_AUTOWAVE, NRS_CONFIRM, '
#                       'NRS_FOCUS, NRS_MIMF.\r\n'
#                       'NIRCAM DISTORTION references for NRC GRISM and NRC '
#                       'TSGRISM.\r\n'
#                       'NIRCAM SPECWCS added empty rmap.\r\n'
#                       'WAVECORR is N/A for anything but NIRSPEC.'],
#                      ['2017-08-01 11:25:01',
#                       'jwst_0352.pmap',
#                       'IMPORTANT --  backward incompatible changes to NIRSPEC '
#                       'WCS reference file formats,  up-to-date calibration '
#                       'code is required to use this context.'],
#                      ['2017-07-14 08:30:27',
#                       'jwst_0348.pmap',
#                       'Delivery of initial TRAPPARS, TRAPDENSITY, and PERSAT '
#                       'rmaps and references for FGS, NIRCAM, NIRISS, NIRSPEC.  '
#                       'MIRI rmaps have been delivered but are currently empty '
#                       'and not referenced by the active MIRI imap while '
#                       'awaiting the delivery of reference files.  MIRI sets '
#                       'these new types to N/A in the MIRI .imap.   To activate '
#                       'them for MIRI,  the initial orphan empty rmaps should '
#                       'be resubmitted prior to the delivery of these MIRI '
#                       'references.'],
#                      ['2017-06-07 09:32:09',
#                       'jwst_0341.pmap',
#                       'Manual updates to MIRI DISTORTION and FILTEROFFSET '
#                       'rmaps to re-classify new files as replacements of older '
#                       'versions with wider USEAFTER coverage dating back to '
#                       '2000 instead of 2014.   The older versions have been '
#                       'removed.'],
#                      ['2017-06-06 15:17:15',
#                       'jwst_0339.pmap',
#                       'Numerous MIRI, NIRSPEC, and NIRCAM reference file '
#                       'deliveries and rmap updates in preparation for the '
#                       'calibration s/w interim release for June 2017.'],
#                      ['2017-04-19 15:13:58',
#                       'jwst_0319.pmap',
#                       'New MIRI RESOL, CUBEPAR types.\r\n'
#                       'Updates MIRI MRS PHOTOM, AREA, NIRCAM PHOTOM.'],
#                      ['2017-02-02 11:00:05',
#                       'jwst_0311.pmap',
#                       'Removed NIRCAM FLATS 0000 and 0010 per Jira CRDS-96'],
#                      ['2017-01-27 15:56:09',
#                       'jwst_0310.pmap',
#                       'Demoted NIRCAM FLATs that matched on FILTER,PUPIL=ANY '
#                       'to N/A to remove conflict with more specific '
#                       'references.'],
#                      ['2017-01-27 13:56:43',
#                       'jwst_0309.pmap',
#                       'New NIRCAM pixel flats.   NIRCAM SSB and ReDCaT team '
#                       'request.'],
#                      ['2017-01-17 16:16:56',
#                       'jwst_0307.pmap',
#                       'Updated MIRI AREA, LINEARITY, FRINGE, WCSREGIONS.  '
#                       'First context change post-build-7.'],
#                      ['2016-12-09 11:06:08',
#                       'jwst_0303.pmap',
#                       'BUILD-7-FINAL      Updated SYSTEM CALVER reference for '
#                       'final B7 cal code versions 0.7.0rc6, rc7, rc8, rc9,  '
#                       'identical with rc5.'],
#                      ['2016-12-08 16:32:31',
#                       'jwst_0302.pmap',
#                       'Modified MIRI FLAT rmap to reclassify remaining cases '
#                       'of READPATT=FAST to apply to FASTGRPAVG as well per '
#                       'Jira CRDS-77.'],
#                      ['2016-12-08 12:24:52',
#                       'jwst_0301.pmap',
#                       'Reverted NIRSPEC REFPIX based on problems with CDP4 '
#                       'related references.'],
#                      ['2016-12-08 10:42:17',
#                       'jwst_0300.pmap',
#                       'Changed NIRSPEC PATHLOSS rmap to handle NRS_BRIGHTOBJ '
#                       'same as NRS_FIXEDSLIT and make  NRS_AUTOWAVE N/A.'],
#                      ['2016-12-07 20:08:33',
#                       'jwst_0299.pmap',
#                       'Manual pmap update for adding modified FGS, MIRI, '
#                       'NIRCAM, NIRISS PATHLOSS as N/A.'],
#                      ['2016-12-07 16:37:55',
#                       'jwst_0298.pmap',
#                       'Deliver updated RMAPs for superbias and extract1d. The '
#                       'Superbias had to change to allow for OR option for IRS2 '
#                       'readout. The Extract1d rmap to resolve a conflict with '
#                       'the latest delivery.'],
#                      ['2016-12-07 16:24:11',
#                       'jwst_0297.pmap',
#                       'Delivery of updated NIRSpec Superbias to correct and '
#                       'issues with the SUBSIZE values. Also an updated  '
#                       'Extract1d file to be used with extract_1d step for '
#                       'NRS_BRIGHTOBJ data'],
#                      ['2016-12-07 16:08:07',
#                       'jwst_0296.pmap',
#                       'Fixed READPATT in NIRSPEC MASK and REFPIX RMAPs.'],
#                      ['2016-12-07 15:37:21',
#                       'jwst_0295.pmap',
#                       'Delivery NIRSpec REFPIX files for IRS2 mode. These are '
#                       'produced by the IDTs and delivered with CDP4'],
#                      ['2016-12-07 15:14:18',
#                       'jwst_0294.pmap',
#                       'Updated NIRSPEC SUPERBIAS rmap to recategorize new '
#                       'superbias files as REAPATT = NRSIRS2 or NRSIRS2RAPID '
#                       'replacing prior files in that category.'],
#                      ['2016-12-07 14:35:07',
#                       'jwst_0293.pmap',
#                       'NIRSPEC updated the existing IRS2 superbias files to '
#                       'have SUBSIZE=2048 in accordance with what the pipeline '
#                       'expects.'],
#                      ['2016-12-07 10:28:37',
#                       'jwst_0292.pmap',
#                       'Updated SYSTEM CALVER rmap for cal code 0.7.0rc5'],
#                      ['2016-12-06 18:13:36',
#                       'jwst_0291.pmap',
#                       'Modified NIRSPEC REFPIX rmap instances of ALLIRS2 to '
#                       'NRSIRS2 or NRSIRS2RAPID.'],
#                      ['2016-12-05 13:28:58',
#                       'jwst_0290.pmap',
#                       'New NIRSpec ALLSLITS superbias reference files.'],
#                      ['2016-12-05 08:41:17',
#                       'jwst_0289.pmap',
#                       'New NIRSpec bias and dark reference files.'],
#                      ['2016-12-02 12:24:27',
#                       'jwst_0288.pmap',
#                       'SYSTEM CALVER reference for Build-7 rc4'],
#                      ['2016-12-01 19:22:14',
#                       'jwst_0287.pmap',
#                       'First NIRSPEC PATHLOSS references,  IFU, MSASPEC, '
#                       'FIXEDSLIT.'],
#                      ['2016-11-28 14:11:25',
#                       'jwst_0285.pmap',
#                       'Changed FGS DISTORTION USEAFTER from 2016-01-01 to '
#                       '2015-06-01 per CRDS Trac-462 and feedback from SDP on '
#                       '2016-11-21.'],
#                      ['2016-11-28 14:01:50',
#                       'jwst_0284.pmap',
#                       'Modified NIRCAM DARK USEAFTER from 2015-10-01 to '
#                       '2015-06-01 per CRDS Trac-462 and test feedback from SDP '
#                       'on 2016-11-21.'],
#                      ['2016-11-28 12:49:59',
#                       'jwst_0283.pmap',
#                       'New MIRI MASK files.'],
#                      ['2016-11-21 14:49:08',
#                       'jwst_0282.pmap',
#                       'Modified NIRSPEC EXTRACT1D rmap to classify '
#                       'NRS_BRIGHTOBJ like NRS_FIXEDSLIT.'],
#                      ['2016-11-21 13:28:08',
#                       'jwst_0281.pmap',
#                       'Updated NIRSPEC AREA USEAFTER to 2014-07-01 per Jira '
#                       'JP-104.'],
#                      ['2016-11-21 09:57:37',
#                       'jwst_0280.pmap',
#                       'Removed oldest NIRISS SATURATION reference. Reapplied '
#                       'remaining reference to all test data by changing '
#                       'USEAFTER to 2014-07-01 per Jira CRDS-81.  Mapped NIRISS '
#                       'DISTORTION AMI WCS to same references as IMAGE per Jira '
#                       'CRDS-56.'],
#                      ['2016-11-17 10:04:14',
#                       'jwst_0278.pmap',
#                       'Updated SYSTEM CALVER to support 0.7.0rc3.'],
#                      ['2016-11-16 18:29:25',
#                       'jwst_0277.pmap',
#                       'MIRI WCS FILTEROFFSET and DISTORTION replacements for '
#                       'MIR_IMAGE cases.'],
#                      ['2016-11-16 17:07:14',
#                       'jwst_0275.pmap',
#                       'Mapped NIRSPEC DARK NRSRAPID cases to NRS+NRSRAPID per '
#                       'Jira CRDS-80.'],
#                      ['2016-11-16 16:56:35',
#                       'jwst_0274.pmap',
#                       'Dummy NIRISS DARK files for NRS2 SUB512 and SUB32 for '
#                       'NRSRAPID.'],
#                      ['2016-11-16 16:13:44',
#                       'jwst_0273.pmap',
#                       'NIRISS DARK,  remove NIS+NISRAPID for SUBARRAY=FULL,  '
#                       'Jira CRDS-79.'],
#                      ['2016-11-16 15:57:49',
#                       'jwst_0272.pmap',
#                       'Updates for NIRSPEC WCS and NIRISS DARK, Jira CRDS-79.'],
#                      ['2016-11-15 17:04:00',
#                       'jwst_0270.pmap',
#                       'FGS MASK USEAFTER adjustment to 2014-07-01 per Jira '
#                       'JP-94.'],
#                      ['2016-11-15 14:21:12',
#                       'jwst_0269.pmap',
#                       'To deliver new FGS reference files for subarrays and '
#                       'read patterns and to deliver corrected reference '
#                       'files.'],
#                      ['2016-11-14 17:31:21',
#                       'jwst_0268.pmap',
#                       'MIRI WCS MIR_CORONCAL + MIR_LYOT for EXTRACT1D and '
#                       'WCSREGIONS per Jira CRDS-57.'],
#                      ['2016-11-14 14:56:32',
#                       'jwst_0267.pmap',
#                       'MIRI DARK MIRIFUSHORT USEAFTER, MIRI DARK FASTGRPAVG\r\n'
#                       '\r\n'
#                       'NIRSPEC NRS_BRIGHTOBJ support'],
#                      ['2016-11-14 09:33:48',
#                       'jwst_0264.pmap',
#                       'New NIRCAM subarray darks.'],
#                      ['2016-11-12 08:17:59',
#                       'jwst_0263.pmap',
#                       'Development largely in response to feedback from SDP on '
#                       'CV3 data,  some independent deliveries,  look at '
#                       'diffs.'],
#                      ['2016-11-01 09:53:58',
#                       'jwst_0237.pmap',
#                       'Added NIRSPEC DFLAT, FFLAT, SFLAT removed NIRSPEC '
#                       'FLAT.  Added support for FGS DISTORTION FGS_FOCUS.   '
#                       'Added NIRSPEC MSAOPER.'],
#                      ['2016-10-17 13:33:27',
#                       'jwst_0231.pmap',
#                       'New NIRISS SUPERBIAS,  MIRI FLATS,  NIRSPEC DFLAT + '
#                       'FFLAT + SFLAT,  SYSTEM CALVER support 0.6.0'],
#                      ['2016-10-03 12:42:00',
#                       'jwst_0223.pmap',
#                       'Since 204 --  additional files for MIRI CDP-6 DARKs, '
#                       'FLATs, READNOISE, RSCD.   Also adds SYSTEM CALVER and '
#                       'DATALVL s/w reference types.  Many NIRISS updates -- '
#                       'AREA, DISTORTION, PHOTOM, DARK, FLAT, IPC, GAIN, '
#                       'LINEARITY, READNOISE, SUPERBIAS, SATURATION.'],
#                      ['2016-08-24 19:06:19',
#                       'jwst_0204.pmap',
#                       'Multiple FGS and NIRISS CV3 deliveries for numerous '
#                       'types.  NIRSPEC SATURATION useafter date correction.  '
#                       'Rmap fix for FGS,  SUBARRAY=FULL to SUBARRAY=GENERIC '
#                       'for  GAIN, LINEARITY, MASK, READNOISE, SUPERBIAS.   '
#                       'Added READPATT to FGS and NIRISS DARK lookups.'],
#                      ['2016-08-03 14:17:10',
#                       'jwst_0197.pmap',
#                       'Updated NIRSPEC DISPERSER, PHOTOM and NIRCAM DARKs.'],
#                      ['2016-06-01 13:53:32',
#                       'jwst_0192.pmap',
#                       'Delivery of new NIRSPEC FPA reference files to correct '
#                       'the extraction location of NRS2 spectra.'],
#                      ['2016-05-18 09:40:19',
#                       'jwst_0191.pmap',
#                       'Delivered MIRI CDP5 files and corrections to several '
#                       'MIRI RMAPs to correct issues with selection of the '
#                       'reference files. Also, updated NIRSpec IMAP.'],
#                      ['2016-05-05 09:44:40',
#                       'jwst_0183.pmap',
#                       'Delivery of new MIRI MRS distortion, regions, specwcs, '
#                       'v2v3 and wavelengthrange reference files derived from '
#                       'CDP5 data and converted to the right format by SSB. '
#                       'Delivery of new NIRSpec camera, collimator, disperser, '
#                       'fore, fpa, ifufore, ifupost, ifuslicer, msa, ote, and '
#                       'wavelengthrange reference files derived from CDP4.  '
#                       'Delivery of FGS pixel area maps and photometric '
#                       'reference files. This delivery corrects the headers of '
#                       'the pixel area files.  Delivery of NIRISS pixel area '
#                       'and photom reference files. The pixel area only '
#                       'corrects header keywords. Changed READPATT=ANY to '
#                       'READPATT=N/A for FGS SUPERBIAS.  Delivery FGS rmaps for '
#                       'photom and pixel area reference files to remove old '
#                       'files that had a different useafter date and were not '
#                       'replaced with the last delivery when they should have.  '
#                       'Delivery of NIRISS rmaps for pixel area map and photom '
#                       'to remove old file that had different useafter and that '
#                       'were not removed with the new delivery.  Changes to '
#                       'NIRSPEC CAMERA, COLLIMATOR, DISPERSER, FORE, FPA, '
#                       'IFUFORE, IFUPOST, IFUSLICER, MSA, OTE, WAVELENGTHRANGE '
#                       'changing handling of various EXP_TYPE.'],
#                      ['2016-04-30 10:49:00',
#                       'jwst_0175.pmap',
#                       'Hand edited to add FGS, MIRI, NIRISS, NIRCAM types '
#                       'ifufore, ifupost, ifuslicer as N/A. pmap only.   '
#                       'Defined EXP_TYPE=MIR_IMAGE as N/A for MIRI EXTRACT1D. '
#                       'Delivery of Combined PHOTOM file for MIRI Imager from '
#                       'CDP5. Delivery Dummy NIRSpec FLAT reference files for '
#                       'MOS data.  Redefined USEAFTER for MIRI FLAT '
#                       'SLITLESSPRISM cases as 2013-09-26.  Added READPATT as a '
#                       'matching parameter for NIRSPEC DARK per jira-crds-19 '
#                       'defining missing values of READPATT in early files as '
#                       'N/A.  Added MIRI FLAT SLITLESSPRISM references back '
#                       'into rmap.'],
#                      ['2016-04-29 16:14:39',
#                       'jwst_0167.pmap',
#                       'Reverted operational context from 175 to 167 following '
#                       'accidental activation of 175 prior to sufficient '
#                       'testing.'],
#                      ['2016-04-29 16:09:58',
#                       'jwst_0175.pmap',
#                       'Updated edit context to jwst_0175.pmap following manual '
#                       'imap and pmap edits which added but did not generate a '
#                       'context.'],
#                      ['2016-04-20 09:04:16',
#                       'jwst_0167.pmap',
#                       'Correction to FGS DARK matching.   NIRSPEC imaging '
#                       'FLATs.   NIRSPEC MOS REFPIX references.  Defined '
#                       'missing types for ALL instruments as N/A.   Defined '
#                       'MIRI imaging FRINGE and STRAYMASK as N/A modes.'],
#                      ['2016-04-08 18:29:46',
#                       'jwst_0161.pmap',
#                       'Delivery of NIRSpec Dark reference files delivered with '
#                       'CDP2'],
#                      ['2016-04-07 14:44:57',
#                       'jwst_0160.pmap',
#                       'Global switch to USEAFTER support for all reference '
#                       'types.   Many build 6 deliveries,  see context diffs.'],
#                      ['2016-02-16 17:30:28',
#                       'jwst_0126.pmap',
#                       'Corrected NIRSPEC LINEARITY SUBARRAY=FULL values to '
#                       'GENERIC.   CRDS #377'],
#                      ['2016-02-15 13:02:00',
#                       'jwst_0125.pmap',
#                       'Extensive build-6 development updates,  difference '
#                       'jwst_105.pmap to jwst_125.pmap for more details.'],
#                      ['2015-11-18 12:58:13',
#                       'jwst_0105.pmap',
#                       'Declared various EXP_TYPE as N/A for 15 WCS types for '
#                       'MIRI, NIRCAM, NIRSPEC. Replacement MIRI distortion '
#                       'references for CRDS #238.'],
#                      ['2015-11-04 14:02:24',
#                       'jwst_0101.pmap',
#                       'Updated operational context for NIRCAM '
#                       'WAVELENGTHRANGE.'],
#                      ['2015-10-31 17:41:40',
#                       'jwst_0100.pmap',
#                       'Defined V2V3 is N/A for NIRSPEC.'],
#                      ['2015-10-31 11:01:45',
#                       'jwst_0099.pmap',
#                       'Corrected WCS rmaps for parameter value typos detected '
#                       'by certify'],
#                      ['2015-10-31 07:50:49',
#                       'jwst_0098.pmap',
#                       'Explicitly declared some EXP_TYPE values as N/A for '
#                       'some WCS types of all instruments except FGS.'],
#                      ['2015-10-30 14:48:14',
#                       'jwst_0097.pmap',
#                       'Manual PMAP update for preceding WCS IMAP manual '
#                       'changes to declare types N/A.'],
#                      ['2015-10-30 14:46:35',
#                       'jwst_0096.pmap',
#                       'Manual PMAP update for preceding WCS IMAP manual '
#                       'changes to declare types N/A.'],
#                      ['2015-10-30 11:38:16',
#                       'jwst_0095.pmap',
#                       'First round addition of ASDF WCS references and '
#                       'EXTRACT1D files.'],
#                      ['2015-10-21 17:04:45',
#                       'jwst_0084.pmap',
#                       'First EXTRACT1D references for MIRI, NIRISS, NIRSPEC.'],
#                      ['2015-10-02 11:28:26',
#                       'jwst_0082.pmap',
#                       'NIRSpec flat-field reference files from the instrument '
#                       'team to support the Build 5 pipeline.'],
#                      ['2015-09-30 16:17:55',
#                       'jwst_0081.pmap',
#                       'Added jwst_miri_regions_0006.fits back to rules,  '
#                       'MIRIFUSHORT SHORT case accidentally deleted during '
#                       'parameter schema change.'],
#                      ['2015-09-16 09:18:20',
#                       'jwst_0080.pmap',
#                       'Added  DETECTOR=MIRFULONG  BAND=N/A  REFERENCE=N/A for '
#                       'MIRI STRAYMASK'],
#                      ['2015-09-11 09:51:40',
#                       'jwst_0079.pmap',
#                       'Added PIXEL AREA rmaps and references for MIRI, NIRCAM, '
#                       'NIRSPEC.  Augmented AREA rmap for NIRISS.'],
#                      ['2015-08-10 10:02:17',
#                       'jwst_0074.pmap',
#                       'Removed FILTER as matching parameter from SATURATION, '
#                       'READNOISE, MASK, LINEARITY, GAIN, and DARK for all '
#                       'instruments.   First suite of real references for '
#                       'NIRISS, minus ILLUM FLAT. bad pixel mask, bias, gain, '
#                       'pixel flat, ipc, linearity, photometric calibration, '
#                       'pixel area, read noise, saturation. Omitted dark since '
#                       'submitted earlier out of sequence, identical, already '
#                       'jwst_niriss_dark_0005.fits.   First suite of real '
#                       'references for NIRISS, minus ILLUM FLAT. bad pixel '
#                       'mask, bias, gain, pixel flat, ipc, linearity, '
#                       'photometric calibration, pixel area, read noise, '
#                       'saturation.'],
#                      ['2015-07-15 10:50:58',
#                       'jwst_0063.pmap',
#                       'Updated context to latest prefetch N/A related tweaks.'],
#                      ['2015-06-28 19:39:54',
#                       'jwst_0061.pmap',
#                       'Changes to designate some WCS types as N/A,  see '
#                       'context differences for more information.'],
#                      ['2015-05-05 08:33:44',
#                       'jwst_0059.pmap',
#                       'Added SUPERBIAS type support and initial stub '
#                       'references for FGS, NIRISS, NIRCAM, NIRSPEC.'],
#                      ['2015-04-13 08:10:26',
#                       'jwst_0053.pmap',
#                       'Level-2a files from the MIRI IDT CDP-3 delivery from '
#                       'November, 2014.\r\n'
#                       'Added MIRI references from 03-29-2015, new FLAT cases, '
#                       'replacement PHOTOM, FRINGE, STRAYMASK files.\r\n'
#                       'Changed DETECTOR=NIRISS to DETECTOR=NIS.   Added '
#                       'READPATT as MIRI READNOISE matching parameter.\r\n'
#                       'Modified MIRI SUBARRAY handling to use GENERIC, FULL, '
#                       'and specific SUBARRAY values.\r\n'
#                       'Modified MIRI FLAT to consistently use ANY and to '
#                       'remove obsolete references 0029 and 0030.'],
#                      ['2015-02-17 11:17:39',
#                       'jwst_0043.pmap',
#                       'Added NIRISS THROUGHPUT references for AMI modes F277W, '
#                       'F380M, F430M, F480M.   Build-4 first draft context.'],
#                      ['2015-01-12 14:23:12',
#                       'jwst_0039.pmap',
#                       'Jira tickets JP-16, 17, 19, 20, 25, 30.  Generally drop '
#                       'FILTER from several MIRI types and add SUBARRAY and '
#                       'SUBARRAY=N/A for existing references except MIRI DARK.  '
#                       'Added new MIRI DARK references explicitly covering '
#                       'SUBARRAY modes,  removed most old DARKs.'],
#                      ['2014-11-25 10:51:09',
#                       'jwst_0036.pmap',
#                       'FGS DETECTOR value switch from FGS1/FGS2 to '
#                       'GUIDER1/GUIDER2.\r\n'
#                       '\r\n'
#                       'Added rmap_relevance expressions for MIRI and NIRSPEC '
#                       'WCS types to generate N/A for unsupported modes instead '
#                       'of raising exceptions which crashed reference '
#                       'prefetch.'],
#                      ['2014-09-25 18:30:27',
#                       'jwst_0034.pmap',
#                       'Build-3 References'],
#                      ['2014-07-24 18:49:03',
#                       'jwst_0025.pmap',
#                       'Replaced PHOTOM references for NIRSPEC and NIRISS.'],
#                      ['2014-07-18 11:34:48',
#                       'jwst_0023.pmap',
#                       'First MIRI PHOTOM reference for MIRIMAGE detector with '
#                       'real data.'],
#                      ['2014-07-08 16:09:39',
#                       'jwst_0022.pmap',
#                       'Multiple MIRI FLAT changes, new references, added '
#                       'SUBARRAY as matching parameter.  See diffs.'],
#                      ['2014-03-26 08:49:12',
#                       'jwst_0013.pmap',
#                       'New context jwst_0013.pmap adds Interpixel Capacitance '
#                       'references for all instruments.'],
#                      ['2014-03-19 10:51:19',
#                       'jwst_0012.pmap',
#                       'Updated for META.INSTRUMENT.TYPE switch to '
#                       'META.INSTRUMENT.NAME\r\n'
#                       'New linearity files for all instruments\r\n'
#                       'New saturation files and rmaps for all instruments'],
#                      ['2013-11-25 09:00:03', 'jwst_0005.pmap', 'set by system'],
#                      ['2013-09-04 00:00:00',
#                       'jwst_0003.pmap',
#                       'Absolute Calibration (photom) additions and '
#                       'replacements.'],
#                      ['2013-07-31 00:00:00',
#                       'jwst_0002.pmap',
# ...
# <p>CRDS - INFO -  &gt;&gt;  </p>
# <p>INFO:CRDS: &gt;&gt;  </p>
# <p>CRDS - INFO -  &gt;&gt; ++++++++++++++++++++++ Error Summary  ++++++++++++++++++++++</p>
# <p>INFO:CRDS: &gt;&gt; ++++++++++++++++++++++ Error Summary  ++++++++++++++++++++++</p>
# <p>CRDS - INFO -  &gt;&gt;  </p>
# <p>INFO:CRDS: &gt;&gt;  </p>
# <p>CRDS - INFO -  &gt;&gt;  HDU#  Name (version)       Type             Warnings  Errors</p>
# <p>INFO:CRDS: &gt;&gt;  HDU#  Name (version)       Type             Warnings  Errors</p>
# <p>CRDS - INFO -  &gt;&gt;  1                          Primary Array    0         0     </p>
# <p>INFO:CRDS: &gt;&gt;  1                          Primary Array    0         0     </p>
# <p>CRDS - INFO -  &gt;&gt;  2     SCI                  Image Array      0         0     </p>
# <p>INFO:CRDS: &gt;&gt;  2     SCI                  Image Array      0         0     </p>
# <p>CRDS - INFO -  &gt;&gt;  3     ERR                  Image Array      0         0     </p>
# <p>INFO:CRDS: &gt;&gt;  3     ERR                  Image Array      0         0     </p>
# <p>CRDS - INFO -  &gt;&gt;  4     DQ                   Image Array      0         0     </p>
# <p>INFO:CRDS: &gt;&gt;  4     DQ                   Image Array      0         0     </p>
# <p>CRDS - INFO -  &gt;&gt;  5     DQ_DEF               Binary Table     0         0     </p>
# <p>INFO:CRDS: &gt;&gt;  5     DQ_DEF               Binary Table     0         0     </p>
# <p>CRDS - INFO -  &gt;&gt;  6     METADATA             Image Array      0         0     </p>
# <p>INFO:CRDS: &gt;&gt;  6     METADATA             Image Array      0         0     </p>
# <p>CRDS - INFO -  &gt;&gt;  7     FITERR               Image Array      0         0     </p>
# <p>INFO:CRDS: &gt;&gt;  7     FITERR               Image Array      0         0     </p>
# <p>CRDS - INFO -  &gt;&gt;  </p>
# <p>INFO:CRDS: &gt;&gt;  </p>
# <p>CRDS - INFO -  &gt;&gt; **** Verification found 0 warning(s) and 0 error(s). ****</p>
# <p>INFO:CRDS: &gt;&gt; **** Verification found 0 warning(s) and 0 error(s). ****</p>
# <p>CRDS - INFO -  Checking JWST datamodels.</p>
# <p>INFO:CRDS: Checking JWST datamodels.</p>
# <p>DEBUG:jwst.datamodels.util:Opening /grp/crds/ingest/jwst/bit/jmiller/jwst_miri_dark_0057.fits as &lt;class &#39;jwst.datamodels.reference.ReferenceQuadModel&#39;&gt;</p>
# <p>CRDS - <span class='orange'>WARNING</span> -  NoTypeWarning : jwst.datamodels.util : model_type not found. Opening /grp/crds/ingest/jwst/bit/jmiller/jwst_miri_dark_0057.fits as a ReferenceQuadModel</p>
# <p>WARNING:CRDS: NoTypeWarning : jwst.datamodels.util : model_type not found. Opening /grp/crds/ingest/jwst/bit/jmiller/jwst_miri_dark_0057.fits as a ReferenceQuadModel</p>
#                 </div>
#
#     </div>
# </div>
#
#
#
#
#
# <div class="accordion">
#     <h3> jwst_miri_dark_0038.rmap -->  <span class='blue'>jwst_miri_dark_0051.rmap</span>  <span class='green'>OK</span></h3>
#     <div>
#
#
#                     <a href='/browse/jwst_miri_dark_0051.rmap'>jwst_miri_dark_0051.rmap</a>
#                     <br/><br/>
#
#                 <div class='log'>
#                     <p>CRDS - INFO -  Certifying &#39;jwst_miri_dark_0051.rmap&#39; as &#39;MAPPING&#39; relative to context &#39;jwst_0504.pmap&#39;</p>
# <p>CRDS - INFO -  Mapping &#39;jwst_miri_dark_0051.rmap&#39; corresponds to &#39;jwst_miri_dark_0038.rmap&#39; from context &#39;jwst_0504.pmap&#39; for checking mapping differences.</p>
# <p>CRDS - INFO -  Checking diffs from &#39;jwst_miri_dark_0038.rmap&#39; to &#39;jwst_miri_dark_0051.rmap&#39;</p>
#                 </div>
#
#     </div>
# </div>
#
#
#
#    <br/>
#   <!-- certify_results -->
#
#
#
#
#     <h3>Differences</h3>
#
#
#
#
#
#
#
# <div class="accordion">
#     <h3>jwst_miri_dark_0038.rmap --> jwst_miri_dark_0051.rmap</h3>
#     <div>
#
#
#         <div>
#           <p>
#             <span style="color:darkblue;">Browse:&nbsp;&nbsp;</span>
#             <a href="/browse/jwst_miri_dark_0038.rmap" class="browse_a">jwst_miri_dark_0038.rmap</a>
#             <span>&nbsp;&nbsp;</span>
#             <a href="/browse/jwst_miri_dark_0051.rmap" class="browse_a">jwst_miri_dark_0051.rmap</a>
#           </p>
#           <br/>
#         </div>
#
#
#
#
#
#
#
#
#
# <div class="accordion">
#     <h3>Logical Diff ('jwst_miri_dark_0038.rmap', 'jwst_miri_dark_0051.rmap')</h3>
#     <div>
#
#                         <table border="1" class="crds_data_table table table-striped table-bordered" width="100%">
#                             <thead>
#                                 <tr>
#
#                                         <th> DETECTOR </th>
#
#                                         <th> READPATT </th>
#
#                                         <th> SUBARRAY </th>
#
#                                         <th> DATE </th>
#
#                                         <th> TIME </th>
#
#                                         <th> DIFFERENCE </th>
#
#                                 </tr>
#                             </thead>
#                             <tbody>
#
#                                 <tr>
#
#                                         <td> MIRIFULONG </td>
#
#                                         <td> SLOW </td>
#
#                                         <td> FULL </td>
#
#                                         <td> 2015-08-01 </td>
#
#                                         <td> 00:00:00 </td>
#
#                                         <td> <span class='orange'>replaced</span> '<a href='/browse/jwst_miri_dark_0083.fits' class='browse_a'>jwst_miri_dark_0083.fits</a>' with '<a href='/browse/jwst_miri_dark_0096.fits' class='browse_a'>jwst_miri_dark_0096.fits</a>' </td>
#
#                                 </tr>
#
#                             </tbody>
#                         </table>
#
#     </div>
# </div>
#
#
#
#
#
#
#
# <div class="accordion">
#     <h3>Text Diff ('jwst_miri_dark_0038.rmap', 'jwst_miri_dark_0051.rmap')</h3>
#     <div>
#
#                         <pre class="program">--- jwst_miri_dark_0038.rmap	2019-03-26 12:01:45.931575521 -0400
# +++ jwst_miri_dark_0051.rmap	2019-03-27 10:11:22.308986259 -0400
# @@ -1,13 +1,13 @@
#  header = {
#      'classes' : ('Match', 'UseAfter'),
# -    'derived_from' : 'jwst_miri_dark_0020.rmap',
# +    'derived_from' : 'jwst_miri_dark_0038.rmap',
#      'filekind' : 'DARK',
#      'instrument' : 'MIRI',
#      'mapping' : 'REFERENCE',
# -    'name' : 'jwst_miri_dark_0038.rmap',
# +    'name' : 'jwst_miri_dark_0051.rmap',
#      'observatory' : 'JWST',
#      'parkey' : (('META.INSTRUMENT.DETECTOR', 'META.EXPOSURE.READPATT', 'META.SUBARRAY.NAME'), ('META.OBSERVATION.DATE', 'META.OBSERVATION.TIME')),
# -    'sha1sum' : 'be93237e370256966e0f26098d54dee690fcdbc0',
# +    'sha1sum' : '3b507e281e83bab64001848ac744286067c7651a',
#      'substitutions' : {
#          'META.SUBARRAY.NAME' : {
#              'GENERIC' : 'N/A',
# @@ -20,7 +20,7 @@ ('MIRIFULONG', 'N/A', 'FULL') : UseAfter
#          '2015-08-01 00:00:00' : 'jwst_miri_dark_0050.fits',
#      }),
#      ('MIRIFULONG', 'SLOW', 'FULL') : UseAfter({
# -        '2015-08-01 00:00:00' : 'jwst_miri_dark_0083.fits',
# +        '2015-08-01 00:00:00' : 'jwst_miri_dark_0096.fits',
#      }),
#      ('MIRIFUSHORT', 'N/A', 'FULL') : UseAfter({
#          '2014-07-01 00:00:00' : 'jwst_miri_dark_0056.fits',
# </pre>
#
#     </div>
# </div>
#
#
#
#
#
#
#
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#     <br/>
#     <h3>Collisions</h3>
#
# <div class="accordion">
#     <h3><span class="warning">Edit Collision Warnings</span></h3>
#     <div>
#
#     <div>
#
#
#             <p class="warning">
#             <a href='/browse/jwst_miri_dark_0051.rmap'>jwst_miri_dark_0051.rmap</a> and <a href='/browse/jwst_miri_dark_0040.rmap'>jwst_miri_dark_0040.rmap</a>
#             were both derived from <a href='/browse/jwst_miri_dark_0038.rmap'>jwst_miri_dark_0038.rmap</a>
#             </p>
#
#             <p class="warning">
#             <a href='/browse/jwst_miri_dark_0051.rmap'>jwst_miri_dark_0051.rmap</a> and <a href='/browse/jwst_miri_dark_0041.rmap'>jwst_miri_dark_0041.rmap</a>
#             were both derived from <a href='/browse/jwst_miri_dark_0038.rmap'>jwst_miri_dark_0038.rmap</a>
#             </p>
#
#             <p class="warning">
#             <a href='/browse/jwst_miri_dark_0051.rmap'>jwst_miri_dark_0051.rmap</a> and <a href='/browse/jwst_miri_dark_0042.rmap'>jwst_miri_dark_0042.rmap</a>
#             were both derived from <a href='/browse/jwst_miri_dark_0038.rmap'>jwst_miri_dark_0038.rmap</a>
#             </p>
#
#             <p class="warning">
#             <a href='/browse/jwst_miri_dark_0051.rmap'>jwst_miri_dark_0051.rmap</a> and <a href='/browse/jwst_miri_dark_0047.rmap'>jwst_miri_dark_0047.rmap</a>
#             were both derived from <a href='/browse/jwst_miri_dark_0038.rmap'>jwst_miri_dark_0038.rmap</a>
#             </p>
#
#             <p class="warning">
#             <a href='/browse/jwst_miri_dark_0051.rmap'>jwst_miri_dark_0051.rmap</a> and <a href='/browse/jwst_miri_dark_0048.rmap'>jwst_miri_dark_0048.rmap</a>
#             were both derived from <a href='/browse/jwst_miri_dark_0038.rmap'>jwst_miri_dark_0038.rmap</a>
#             </p>
#
#             <p class="warning">
#             <a href='/browse/jwst_miri_dark_0051.rmap'>jwst_miri_dark_0051.rmap</a> and <a href='/browse/jwst_miri_dark_0049.rmap'>jwst_miri_dark_0049.rmap</a>
#             were both derived from <a href='/browse/jwst_miri_dark_0038.rmap'>jwst_miri_dark_0038.rmap</a>
#             </p>
#
#             <p class="warning">
#             <a href='/browse/jwst_miri_dark_0051.rmap'>jwst_miri_dark_0051.rmap</a> and <a href='/browse/jwst_miri_dark_0050.rmap'>jwst_miri_dark_0050.rmap</a>
#             were both derived from <a href='/browse/jwst_miri_dark_0038.rmap'>jwst_miri_dark_0038.rmap</a>
#             </p>
#
#
#     <br/>
#     <p>A file was derived from the same parent file as one or more others.
#
#     <p>Possibly two people edited the same file at the same time
#     and will not incorporate one another's changes.
#
#     <p>This warning is expected whenever you derive a new context from a historical
#     context which already has descendents, i.e. typically when you derive from
#     a context other than the default editing context.
#
#     <p class="warning">If this is an unexplained collision, consider cancelling
#     this submission.
#     </div>
#
#     </div>
# </div>
#
#
#
#
#
#
#     <br/>
#
#
#
#
#
# <script src="/static/jpoll.js" type="text/javascript" language="javascript"></script>
# <script src="/static/jpoll_open.js" type="text/javascript" language="javascript"></script>
# <script src="/static/jquery.form.js" type="text/javascript" language="javascript"></script>
#
#
#
#
#     <div id="confirm_or_cancel">
#         <h3>Confirm or Cancel Submission</h3>
#         <form method="post" action="/submit_confirm/" enctype="multipart/form-data"
#             class="jpoll_ajax_html_form"
#             onsubmit='return crds.submit_confirm_or_cancel();' >  <input type='hidden' name='csrfmiddlewaretoken' value='esgu5o31icfEpqWrEm5ne7kySybk7iduk6Dt9IePXMkVW2hFoBckeb3jKOzkcRVv' />
#             <input type='hidden' name='results_id' value="812f9201-8f86-4cfb-8d48-014a107a855c" />
#             <input type="submit" name="button" value="confirm" class="green"
#                    title="Approve submission results and proceed with delivery.">
#             <input type="submit" name="button" value="cancel"  class="red"
#                    title="Discard this submission.">
#             <input type="submit" name="button" value="force"  class="orange"
#                    title="Ignore locks and originating user.  Approve submission, may lead to collisions.">
#         </form>
#     </div>
#
#
#
# <script type="application/javascript">
#
#     var submit_kind;
#     $("input[type='submit']").click(function () { submit_kind = this.value; });
#
#     crds.submit_confirm_or_cancel = function () {
#         // crds.setup_status_display("Confirmation Status");
#         if (submit_kind == "force") {
#             if (!confirm("CAUTION: Forcing confirmation can lead to colliding deliveries.")) {
#                return false;
#             };
#         }
#         if (submit_kind == "confirm" || submit_kind == "force") {
#             crds.set_info_box({
#                 text: "CONFIRMING...  This may take a minute or so to update the database.",
#                  css: {color: "green"},
#             });
#         } else {
#             if (!confirm("Abort submission?")) {
#                 return false;
#             };
#             crds.set_info_box({
#                 text: "CANCELLING... This may take a minute or so to update the database.",
#                  css: {color: "red"},
#             });
#         };
#         $("input[type='submit']").hide();
#         crds.lock_timeout_action = function () { };
#         return true;
#     };
#
#     crds.lock_timeout_action = function () {
#         $("input[value='confirm']").hide();
#         $("input[value='cancel']").hide();
#         $("input[value='force']").hide();
#         $.ajax({url:"/logout/"});
#         crds.set_info_box({
#            text: "LOCK LOST...  Log back in to cancel or force delivery.",
#            css: {color: "red"},
#         });
#     };
#
# </script>
#
#
#
#
#
#         <br/>
#         <div id="crds_info_box" class="full_width">
#         </div>
#
#
#
# <div style="margin: 0 0 0 0; padding: 3px; width:100%; background: darkblue; line-height: 0.5em;"> &nbsp; </div>
#
#
#
#         <div class="help"></div>
#
# 	<script type="text/javascript">$("#contents").show();</script>
#
#     </div>
#
#
#         <script type="text/javascript">
#             crds.poll_lock_status();
#             crds.lock_timer_interval = setInterval(crds.poll_lock_status, 5000);
#         </script>
#
#
#
# <script type="text/javascript">
#     $(function() {
#         var tables = $(".crds_data_table");
#         tables.each(function (index, table) {
#             $(table).hide();
#             $(table).attr({"class":"display cell-border"});
#             $(table).css({"font-size":"0.8em"});
#             $(table).dataTable({
#                 "aLengthMenu": [[50, 500, 5000, -1], [50, 500, 5000, "All"]],
#                 "iDisplayLength" : -1,
#             });
#             $(table).show();
#             $(table).attr({"class":"display"});
#         });
#     });
# </script>
#
#
# </div>
#
# <script>
#   $( function () {
#     $( document ).tooltip();
#   });
# </script>
#
#   </body>
# </html>
#
# 2019-03-27 10:11:39,112 - CRDS - DEBUG -  ---------------------------------------------------------------------------
# DEBUG:CRDS: ---------------------------------------------------------------------------
# 2019-03-27 10:11:39,115 - CRDS - INFO -  0 errors
# INFO:CRDS: 0 errors
# 2019-03-27 10:11:39,115 - CRDS - INFO -  0 warnings
# INFO:CRDS: 0 warnings
# 2019-03-27 10:11:39,115 - CRDS - INFO -  27 infos
# INFO:CRDS: 27 infos
# 2019-03-27 10:11:39,115 - CRDS - INFO -  STARTED 2019-03-27 10:09:40.80
# INFO:CRDS: STARTED 2019-03-27 10:09:40.80
# 2019-03-27 10:11:39,115 - CRDS - INFO -  STOPPED 2019-03-27 10:11:39.11
# INFO:CRDS: STOPPED 2019-03-27 10:11:39.11
# 2019-03-27 10:11:39,115 - CRDS - INFO -  ELAPSED 0:01:58.30
# INFO:CRDS: ELAPSED 0:01:58.30
